# %%
import camelot
import json
import os
import re

# %%
def get_continued_tables(tables, threshold):

    continued_tables = {}
    previous_table = False
    group_counter = 0

    # typical height of a pdf is 842 points and bottom margins are anywhere between 56 and 85 points
    # therefore, accounting for margins, 792
    page_height = 792

    # iterate over the tables
    for i, table in enumerate(tables):

        # if a previous table exists (remember, we start with this as false)
        # and the previous table was on the previous page
        # and the number of columns of both tables is the same
        if previous_table and table.page == previous_table.page + 1 and len(table.cols) == len(previous_table.cols):

            # get the bottom coordinate of the previous table
            # note that for pdfs the origin (0, 0) typically starts from the bottom-left corner of the page,
            # with the y-coordinate increasing as you move upwards
            # this is why for {x0, y0, x1, y1} we need the y0 as the bottom
            previous_table_bottom = previous_table._bbox[1]

            # get the top coordinate of the current table
            # for {x0, y0, x1, y1} we need the y1 as the top
            current_table_top = table._bbox[3]

            # if the previous table ends in the last 15% of the page and the current table starts in the first 15% of the page
            if previous_table_bottom < (threshold / 100) * page_height and current_table_top > (1 - threshold / 100) * page_height:

                # if we don't have started this group of tables
                if (continued_tables.get(group_counter) is None):

                    # start by adding the first table
                    continued_tables[group_counter] = [previous_table]

                # add any of the sunsequent tables to the group
                continued_tables[group_counter].append(table)

            # if this is not a continuation of the previous table
            else:

                # increment the group number
                group_counter += 1;

        # if this is not a continuation of the previous table
        else:

            # increment the group number
            group_counter += 1;

        # the current table becomes the previous table for the next iteration
        previous_table = table

    # transform the dictionary into an array of arrays
    continued_tables = [value for value in continued_tables.values()]

    # return the combined tables
    return continued_tables

# %%
def table_to_json(table_data, table_info):
    """Convert table data to JSON format"""
    if not table_data:
        return {}
    
    # Create JSON structure
    json_data = {
        "metadata": {
            "source_file": table_info["source_file"],
            "page": table_info["page"],
            "table_order": table_info["order"],
            "total_rows": len(table_data),
            "total_columns": len(table_data[0]) if table_data else 0
        },
        "headers": [],
        "data": []
    }
    
    # Add headers (first row)
    if len(table_data) > 0:
        headers = [str(cell).strip() for cell in table_data[0]]
        
        # Replace first 3 headers with fixed names
        if len(headers) >= 1:
            headers[0] = "STT"
        if len(headers) >= 2:
            headers[1] = "hang_hoa"
        if len(headers) >= 3:
            headers[2] = "yeu_cau_ky_thuat"
            
        json_data["headers"] = headers
        
        # Add data rows (skip header)
        for i, row in enumerate(table_data[1:], 1):
            row_dict = {}
            for j, cell in enumerate(row):
                # Use header as key, fallback to column index if header is empty
                key = json_data["headers"][j] if j < len(json_data["headers"]) and json_data["headers"][j] else f"column_{j}"
                row_dict[key] = str(cell).strip()
            
            json_data["data"].append({
                "row_index": i,
                "values": row_dict
            })
    
    return json_data

# %%
def get_biggest_table(pdf_path, threshold):
    tables = camelot.read_pdf(pdf_path, flavor = 'lattice', pages = 'all')
    continued_tables = get_continued_tables(tables, threshold)

    # get the name of the PDF file we are processing (without the extension)
    pdf_file_name = os.path.splitext(os.path.basename(pdf_path))[0]

    processed = []
    all_table_jsons = []

    # iterate over found tables
    for i, table in enumerate(tables):

        # if table was already processed as part of a group
        if table in processed: continue

        # check if the current table is a continued table
        is_continued = any(table in sublist for sublist in continued_tables)

        # collect all table data (current table + continued tables if any)
        all_table_data = list(table.data)

        # if the current table is a continued table, append all subsequent continued tables data
        if is_continued:

            # get the index of the group in "continued_tables" associated with the current table
            group_index = next(index for index, sublist in enumerate(continued_tables) if table in sublist)

            # iterate over the tables in said group and append their data
            for continued_table in continued_tables[group_index]:

                # skip the current table as it's already added
                if continued_table == table or continued_table in processed: continue

                # append the data of the continued table (skip header for subsequent tables)
                all_table_data.extend(continued_table.data[1:] if len(continued_table.data) > 1 else [])

                # keep track of processed tables
                processed.append(continued_table)

        # convert to JSON
        table_info = {
            "source_file": pdf_file_name,
            "page": table.parsing_report['page'],
            "order": table.parsing_report['order']
        }
        
        json_data = table_to_json(all_table_data, table_info)
        all_table_jsons.append(json_data)
        
        # mark current table as processed
        processed.append(table)

    # find the table with the most rows
    if all_table_jsons:
        largest_table = max(all_table_jsons, key=lambda x: x.get('metadata', {}).get('total_rows', 0))
        
        # return the JSON of the largest table
        print(json.dumps(largest_table, ensure_ascii=False, indent=2))
        return largest_table
    else:
        print("No tables found in the PDF.")
        return None

# %%
hello = get_biggest_table("D:/study/LammaIndex/documents/test.pdf",50)
# Out:
# {
#   "metadata": {
#     "source_file": "test",
#     "page": 1,
#     "table_order": 1,
#     "total_rows": 15,
#     "total_columns": 3
#   },
#   "headers": [
#     "STT",
#     "hang_hoa",
#     "yeu_cau_ky_thuat"
#   ],
#   "data": [
#     {
#       "row_index": 1,
#       "values": {
#         "STT": "I",
#         "hang_hoa": "Bộ chuyển đổi nguồn 220VAC/ \n48VDC (kèm theo 02 dàn acquy \n200Ah)",
#         "yeu_cau_ky_thuat": ""
#       }
#     },
#     {
#       "row_index": 2,
#       "values": {
#         "STT": "1",
#         "hang_hoa": "Yêu cầu chung",
#         "yeu_cau_ky_thuat": "-  Các loại thiết bị, vật tư, phụ kiện phải có nguồn gốc xuất xứ rõ ràng, có chứng nhận chất lượng sản \nphẩm của nhà sản xuất. \n-  Thiết bị mới 100% chưa qua sử dụng \n-  Thiết bị phải được sản xuất từ năm 2021 trở lại đây \n-  Tuân thủ tiêu chuẩn IEC 60950-1 \n-  Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của \ntừng khối. \n-  Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp \nacquyhoàn chỉnh. \n-  Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng."
#       }
#     },
#     {
#       "row_index": 3,
#       "values": {
#         "STT": "2",
#         "hang_hoa": "Cấu hình thiết bị nguồn",
#         "yeu_cau_ky_thuat": "- Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4 \n- Công suất mỗi module chỉnh lưu: ≥ 3000W \n- Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module \n- Attomat DC: \n+ PL (Priority LLVD) \n● \nLoại 32A: ≥ 02 cái \n● \nLoại 16A: ≥ 01 cái \n+ NPL (Non Priority LLVD): \n● \nLoại 63A: ≥ 02 cái \n● \nLoại 32A: ≥ 03 cái \n● \nLoại 16A: ≥ 02 cái \n+ Attomat cho acquy: \n●  Loại 125A: ≥ 02 cái"
#       }
#     },
#     {
#       "row_index": 4,
#       "values": {
#         "STT": "3",
#         "hang_hoa": "Đầu vào AC",
#         "yeu_cau_ky_thuat": "-  Sử dụng được các điện áp L＋N＋PE/220VAC  \n-  Dải điện áp đầu vào từ 85VAC ÷ 300VAC \n-  Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz. \n-  Có tính năng chống sét"
#       }
#     },
#     {
#       "row_index": 5,
#       "values": {
#         "STT": "4",
#         "hang_hoa": "Đầu ra DC",
#         "yeu_cau_ky_thuat": "-  Điện áp đầu ra danh định -48VDC, cực dương đấu đất \n-  Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC \n-  Độ ổn định điện áp đầu ra: ≤1%"
#       }
#     },
#     {
#       "row_index": 6,
#       "values": {
#         "STT": "",
#         "hang_hoa": "",
#         "yeu_cau_ky_thuat": "-  Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz) \n-  Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)"
#       }
#     },
#     {
#       "row_index": 7,
#       "values": {
#         "STT": "5",
#         "hang_hoa": "Yêu cầu với module chỉnh lưu \n(Rectifier)",
#         "yeu_cau_ky_thuat": "-  Công suất mỗi module chỉnh lưu: ≥ 3000W \n-  Hệ số công suất (power factor) của Rectifier: ≥0.99 với tải từ 50÷100% \n-  Hiệu suất đỉnh (peak efficiency) module rectifier: ≥ 0,95 \n-  Tổng độ méo hài THD của Rectifier: ≤5% với tải từ 50÷100% tại điện áp 220VAC \n-  Rectifier thay thế nóng được khi tủ nguồn đang hoạt động. \n-  Rectifier hoạt động theo cơ chế chia tải \n-  Trạng thái hoạt động của Rectifier được hiển thị bằng đèn LED. \n-  Có khả năng đặt tốc độ quạt theo chế độ tự động hoặc full tốc độ."
#       }
#     },
#     {
#       "row_index": 8,
#       "values": {
#         "STT": "6",
#         "hang_hoa": "Tính năng của thiết bị nguồn",
#         "yeu_cau_ky_thuat": "-  Bộ nguồn có chức năng cấp nguồn DC cho thiết bị và nạp cho acquy ở các chế độ nạp đệm và nạp \nbổ sung. Quá trình nạp phải được chuyển tự động giữa các chế độ. Bộ nguồn sử dụng công nghệ \nchuyển mạch (switch mode). \n-  Bộ nguồn phải tự động chuyển đổi đường cấp nguồn cho phụ tải khi điện áp AC vào bộ nguồn bị \nngắt từ bộ nắn nạp sang nguồn dự phòng nóng acquy mà không có sự gián đoạn nào. Sau khi việc \ncấp điện AC được phục hồi thì bộ thiết bị điều khiển phải đảm bảo tự động chuyển đổi lại trạng thái \nlàm việc ban đầu và cũng không có sự gián đoạn nào. \n-  Hệ thống có trang bị chức năng LLVD (Load Low Voltage Disconection). \n-  Phải giám sát được hoạt động của hệ thống nguồn từ xa qua cổng Ethernet (web pages/ SNMP).  \n-  Phải có mạch bảo vệ lắp sẵn trong tủ nguồn để chống lại hiện tượng quá điện áp, quá tải và dòng \nngắn mạch, bảo vệ acquy không cho phóng điện khi điện áp quá thấp. \n-  Hệ thống nguồn phải có tiếp đất, chống sét \n-  Tính năng cảnh báo: bao gồm tối thiểu nhưng không giới hạn khả năng xuất cảnh báo như: \n●  Lỗi AC đầu vào của Rectifier \n●  Lỗi quá nhiệt của Rectifier \n●  Lỗi quạt của Rectifier \n●  Lỗi của Rectifier \n●  Mất điện AC \n●  Cảnh báo AC đầu vào thấp \n●  Cảnh báo AC đầu vào cao \n●  Cảnh báo DC cao \n●  Cảnh báo DC thấp \n●  Cảnh báo LVD \n●  Cảnh báo dòng sạc Ắc quy cao"
#       }
#     },
#     {
#       "row_index": 9,
#       "values": {
#         "STT": "7",
#         "hang_hoa": "Khối điều khiển và hiển thị",
#         "yeu_cau_ky_thuat": "-  Hiển thị bằng màn hình LCD, có khả năng hiển thị các thông số điện áp (U), dòng điện (I) và một \nsố thông số khác như: cảnh báo, hiển thị chế độ nạp acquy."
#       }
#     },
#     {
#       "row_index": 10,
#       "values": {
#         "STT": "",
#         "hang_hoa": "",
#         "yeu_cau_ky_thuat": "-  Bảng điều khiển phải gồm có nút điều khiển để thiết lập và điều chỉnh các thông số, màn hình hiển \nthị các thông số vận hành, đèn chỉ thị trạng thái, các cổng truy cập và giám sát từ xa. \n-  Cổng kết nối: RS485, Ethernet, USB \n-  Giao thức kết nối: IPv4, HTTPS, SNMP V2/V3 \n-  Sử dụng màn hình LCD màu  \n-  Cho phép cài đặt, thiết lập các thông số cho thiết bị nguồn. \n-  Bảng điều khiển được đặt trước mặt máy, dễ quan sát."
#       }
#     },
#     {
#       "row_index": 11,
#       "values": {
#         "STT": "8",
#         "hang_hoa": "Điều kiện làm việc",
#         "yeu_cau_ky_thuat": "●  Dải nhiệt độ từ -10°C đến +60°C \n●  Dải độ ẩm từ 5% đến 95%"
#       }
#     },
#     {
#       "row_index": 12,
#       "values": {
#         "STT": "9",
#         "hang_hoa": "Hệ thống làm mát",
#         "yeu_cau_ky_thuat": "-  Làm mát bằng quạt"
#       }
#     },
#     {
#       "row_index": 13,
#       "values": {
#         "STT": "10",
#         "hang_hoa": "Điều kiện bảo hành",
#         "yeu_cau_ky_thuat": "-  Có cơ sở bảo hành chính hãng thiết bị nguồn tại Việt Nam."
#       }
#     },
#     {
#       "row_index": 14,
#       "values": {
#         "STT": "11",
#         "hang_hoa": "Acquy kèm theo",
#         "yeu_cau_ky_thuat": "02 dàn Ac quy 12V - 200Ah (08 bình): \n-  Ắcquy phải là loại Axít chì, vỏ bình kín không phải bảo dưỡng (loại VLRA) và không ảnh hưởng \nđến môi trường, cho phép bố trí chung trong phòng máy với các thiết bị điện khác, chất liệu vỏ bình \nacquy là nhựa ABS. \n-  Thời hạn sản xuất acquy không quá 1 năm tính từ ngày cấp hàng. \n-  Điện áp nạp ở 25oC: \n  + Chế độ nạp đệm (Float mode): 2.25V/cell hoặc 13.6V/bình \n  + Chế độ nạp bổ sung (Boost mode): 2.35-2.4V/cell hoặc 14.4V/bình \n-  Độ tự xả sau 03 tháng: dung lượng ắcquy ≥ 90% dung lượng danh định \n- Đầu cực: dạng M6 hoặc M8 \n- Quy cách dàn ắcquy: \n  + Mỗi dàn ắcquy gồm 4 bình. \n  + Điện áp danh định mỗi bình là 12VDC. \n  + Điện áp cả tổ là 48VDC \n-  Dung lượng dàn ắcquy≥ 200Ah. \n-  Nội trở ≤ 4.5mΩ \n-  Mỗi dàn acquy phải gồm đầy đủ cáp nối giữa các bình \n-  Kèm phụ kiện lắp đặt (cầu nối giữa các bình, kẹp cực, giá đỡ..)"
#       }
#     }
#   ]
# }

# %%
data = hello["data"]

# %%
import uuid
def clean_text(text):
    """Làm sạch text, loại bỏ ký tự xuống dòng thừa"""
    return re.sub(r'\n+', '', text.strip())

def split_requirements(text):
    """Tách các yêu cầu dựa trên dấu gạch đầu dòng"""
    requirements = []
    lines = text.split('\n')
    for line in lines:
        line = line.strip()
        if line.startswith('- '):
            requirements.append(line[2:].strip())
        elif line and not any(line.startswith(prefix) for prefix in ['- ']):
            if requirements:
                requirements[-1] += ' ' + line
            else:
                requirements.append(line)
    return requirements

def generate_random_key():
    """Tạo key random 5 ký tự từ UUID"""
    return str(uuid.uuid4()).replace('-', '')[:5].upper()

def convert_to_new_format(data):
    result = []
    current_product = None
    current_category = None
    
    for item in data:
        values = item['values']
        stt_raw  = values['STT']
        hang_hoa = clean_text(values['hang_hoa'])
        yeu_cau = values['yeu_cau_ky_thuat']


        stt = stt_raw.strip()

        roman_pattern = r'^(VII|VIII|IX|X|XI|XII|I{1,3}|IV|V|VI)\s+(.+)'
        roman_match = re.match(roman_pattern, stt)
        # Nếu STT là số La Mã (I, II, III...) thì đây là tên sản phẩm
        hang_hoa_roman_match = re.match(roman_pattern, hang_hoa)
        if roman_match and not hang_hoa and not yeu_cau:
            if current_product:
                result.append(current_product)
            
            roman_num = roman_match.group(1)  # Số La Mã
            product_name = roman_match.group(2)  # Tên sản phẩm
            
            current_product = {
                "ten_san_pham": product_name,
                "cac_muc": []
            }
            current_category = None
        elif hang_hoa_roman_match and not stt_raw and not yeu_cau:
            if current_product:
                result.append(current_product)
            
            roman_num = hang_hoa_roman_match.group(1)  # Số La Mã
            product_name = hang_hoa_roman_match.group(2)  # Tên sản phẩm
            
            current_product = {
                "ten_san_pham": product_name,
                "cac_muc": []
            }
            current_category = None        
        
        elif stt in ['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X', 'XI', 'XII', 'XIII', 'XIV']:
            if current_product:
                result.append(current_product)
            
            current_product = {
                "ten_san_pham": hang_hoa,
                "cac_muc": []
            }
            current_category = None
            
        # Nếu STT là số (1, 2, 3...) thì đây là danh mục
        elif stt.isdigit():
            current_category = {
                "ten_hang_hoa": hang_hoa,
                "thong_so_ky_thuat": {}
            }
            
            # Xử lý yêu cầu kỹ thuật cho danh mục
            if yeu_cau.strip():
                requirements = split_requirements(yeu_cau)
                for req in requirements:
                    key = generate_random_key()  # Tạo key random
                    current_category["thong_so_ky_thuat"][key] = clean_text(req)
            if current_product:
                current_product["cac_muc"].append(current_category)
                
        # Nếu STT trống thì đây là thông số kỹ thuật chi tiết
        elif stt == '' and current_category and hang_hoa:
            # Tạo key random cho thông số kỹ thuật
            key = generate_random_key()
            
            # Làm sạch tên hàng hóa và yêu cầu kỹ thuật
            clean_hang_hoa = clean_text(hang_hoa)
            clean_yeu_cau = clean_text(yeu_cau)
            
            current_category["thong_so_ky_thuat"][key] = [clean_hang_hoa, clean_yeu_cau]
        elif stt == '' and current_category and not hang_hoa:
            if yeu_cau.strip():
                requirements = split_requirements(yeu_cau)
                
                # Lấy key cuối cùng trong thong_so_ky_thuat (nếu có)
                existing_keys = list(current_category["thong_so_ky_thuat"].keys())
                last_key = existing_keys[-1] if existing_keys else None
                
                for req in requirements:
                    clean_req = clean_text(req)
                    
                    # Kiểm tra chữ cái đầu có viết hoa HOẶC có gạch đầu dòng không
                    has_dash = req.strip().startswith('- ')
                    has_uppercase = clean_req and clean_req[0].isupper()
                    
                    if has_uppercase or has_dash:
                        # Chữ đầu viết hoa HOẶC có gạch đầu dòng -> tạo key mới
                        key = generate_random_key()
                        current_category["thong_so_ky_thuat"][key] = clean_req
                        last_key = key
                    else:
                        # Chữ đầu không viết hoa VÀ không có gạch đầu dòng -> nối vào key trước đó
                        if last_key and last_key in current_category["thong_so_ky_thuat"]:
                            current_category["thong_so_ky_thuat"][last_key] += " " + clean_req
                        else:
                            # Nếu không có key trước đó thì vẫn tạo key mới
                            key = generate_random_key()
                            current_category["thong_so_ky_thuat"][key] = clean_req
                            last_key = key
    
    # Thêm sản phẩm cuối cùng
    if current_product:
        result.append(current_product)
    
    return result

# Chuyển đổi dữ liệu
converted_data = convert_to_new_format(data)

# %%
converted_data
# Out:
# [{'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'cac_muc': [{'ten_hang_hoa': 'Yêu cầu chung',
#     'thong_so_ky_thuat': {'69A25': 'Các loại thiết bị, vật tư, phụ kiện phải có nguồn gốc xuất xứ rõ ràng, có chứng nhận chất lượng sản phẩm của nhà sản xuất.',
#      '071A1': 'Thiết bị mới 100% chưa qua sử dụng',
#      'BEAC1': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#      '19489': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#      '80D06': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#      '3156F': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#      '140CB': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.'}},
#    {'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#     'thong_so_ky_thuat': {'E5887': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#      '477EB': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#      '48C02': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#      'AE97F': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái'}},
#    {'ten_hang_hoa': 'Đầu vào AC',
#     'thong_so_ky_thuat': {'7B62B': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#      '76695': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#      'DC333': 'Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.',
#      '84BCD': 'Có tính năng chống sét'}},
#    {'ten_hang_hoa': 'Đầu ra DC',
#     'thong_so_ky_thuat': {'70354': 'Điện áp đầu ra danh định -48VDC, cực dương đấu đất',
#      'B6CD3': 'Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC',
#      '060AE': 'Độ ổn định điện áp đầu ra: ≤1%',
#      '7559A': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#      '57408': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)'}},
#    {'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#     'thong_so_ky_thuat': {'C4531': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#      '67B0A': 'Hệ số công suất (power factor) của Rectifier: ≥0.99 với tải từ 50÷100%',
#      '11499': 'Hiệu suất đỉnh (peak efficiency) module rectifier: ≥ 0,95',
#      'A1F38': 'Tổng độ méo hài THD của Rectifier: ≤5% với tải từ 50÷100% tại điện áp 220VAC',
#      'FA3B9': 'Rectifier thay thế nóng được khi tủ nguồn đang hoạt động.',
#      '81515': 'Rectifier hoạt động theo cơ chế chia tải',
#      '604AA': 'Trạng thái hoạt động của Rectifier được hiển thị bằng đèn LED.',
#      '50659': 'Có khả năng đặt tốc độ quạt theo chế độ tự động hoặc full tốc độ.'}},
#    {'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#     'thong_so_ky_thuat': {'26D8D': 'Bộ nguồn có chức năng cấp nguồn DC cho thiết bị và nạp cho acquy ở các chế độ nạp đệm và nạp bổ sung. Quá trình nạp phải được chuyển tự động giữa các chế độ. Bộ nguồn sử dụng công nghệ chuyển mạch (switch mode).',
#      '927A0': 'Bộ nguồn phải tự động chuyển đổi đường cấp nguồn cho phụ tải khi điện áp AC vào bộ nguồn bị ngắt từ bộ nắn nạp sang nguồn dự phòng nóng acquy mà không có sự gián đoạn nào. Sau khi việc cấp điện AC được phục hồi thì bộ thiết bị điều khiển phải đảm bảo tự động chuyển đổi lại trạng thái làm việc ban đầu và cũng không có sự gián đoạn nào.',
#      '3A2AF': 'Hệ thống có trang bị chức năng LLVD (Load Low Voltage Disconection).',
#      '32FAA': 'Phải giám sát được hoạt động của hệ thống nguồn từ xa qua cổng Ethernet (web pages/ SNMP).',
#      'B279E': 'Phải có mạch bảo vệ lắp sẵn trong tủ nguồn để chống lại hiện tượng quá điện áp, quá tải và dòng ngắn mạch, bảo vệ acquy không cho phóng điện khi điện áp quá thấp.',
#      'B23B7': 'Hệ thống nguồn phải có tiếp đất, chống sét',
#      '2DEA0': 'Tính năng cảnh báo: bao gồm tối thiểu nhưng không giới hạn khả năng xuất cảnh báo như: ●  Lỗi AC đầu vào của Rectifier ●  Lỗi quá nhiệt của Rectifier ●  Lỗi quạt của Rectifier ●  Lỗi của Rectifier ●  Mất điện AC ●  Cảnh báo AC đầu vào thấp ●  Cảnh báo AC đầu vào cao ●  Cảnh báo DC cao ●  Cảnh báo DC thấp ●  Cảnh báo LVD ●  Cảnh báo dòng sạc Ắc quy cao'}},
#    {'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#     'thong_so_ky_thuat': {'6F7C6': 'Hiển thị bằng màn hình LCD, có khả năng hiển thị các thông số điện áp (U), dòng điện (I) và một số thông số khác như: cảnh báo, hiển thị chế độ nạp acquy.',
#      '12F66': 'Bảng điều khiển phải gồm có nút điều khiển để thiết lập và điều chỉnh các thông số, màn hình hiển thị các thông số vận hành, đèn chỉ thị trạng thái, các cổng truy cập và giám sát từ xa.',
#      'C65FF': 'Cổng kết nối: RS485, Ethernet, USB',
#      '64DF6': 'Giao thức kết nối: IPv4, HTTPS, SNMP V2/V3',
#      '4C891': 'Sử dụng màn hình LCD màu',
#      '46E2F': 'Cho phép cài đặt, thiết lập các thông số cho thiết bị nguồn.',
#      '34694': 'Bảng điều khiển được đặt trước mặt máy, dễ quan sát.'}},
#    {'ten_hang_hoa': 'Điều kiện làm việc',
#     'thong_so_ky_thuat': {'D0F05': '●  Dải nhiệt độ từ -10°C đến +60°C ●  Dải độ ẩm từ 5% đến 95%'}},
#    {'ten_hang_hoa': 'Hệ thống làm mát',
#     'thong_so_ky_thuat': {'CC15E': 'Làm mát bằng quạt'}},
#    {'ten_hang_hoa': 'Điều kiện bảo hành',
#     'thong_so_ky_thuat': {'A534E': 'Có cơ sở bảo hành chính hãng thiết bị nguồn tại Việt Nam.'}},
#    {'ten_hang_hoa': 'Acquy kèm theo',
#     'thong_so_ky_thuat': {'FF244': '02 dàn Ac quy 12V - 200Ah (08 bình):',
#      'CEBE4': 'Ắcquy phải là loại Axít chì, vỏ bình kín không phải bảo dưỡng (loại VLRA) và không ảnh hưởng đến môi trường, cho phép bố trí chung trong phòng máy với các thiết bị điện khác, chất liệu vỏ bình acquy là nhựa ABS.',
#      'ECC21': 'Thời hạn sản xuất acquy không quá 1 năm tính từ ngày cấp hàng.',
#      '49AD6': 'Điện áp nạp ở 25oC: + Chế độ nạp đệm (Float mode): 2.25V/cell hoặc 13.6V/bình + Chế độ nạp bổ sung (Boost mode): 2.35-2.4V/cell hoặc 14.4V/bình',
#      '0A99A': 'Độ tự xả sau 03 tháng: dung lượng ắcquy ≥ 90% dung lượng danh định',
#      'A5FB0': 'Đầu cực: dạng M6 hoặc M8',
#      '39D1A': 'Quy cách dàn ắcquy: + Mỗi dàn ắcquy gồm 4 bình. + Điện áp danh định mỗi bình là 12VDC. + Điện áp cả tổ là 48VDC',
#      'A8053': 'Dung lượng dàn ắcquy≥ 200Ah.',
#      '53371': 'Nội trở ≤ 4.5mΩ',
#      '82FFB': 'Mỗi dàn acquy phải gồm đầy đủ cáp nối giữa các bình',
#      '28EC9': 'Kèm phụ kiện lắp đặt (cầu nối giữa các bình, kẹp cực, giá đỡ..)'}}]}]

# %%
context_queries = {}  # Dict chứa thông tin chi tiết theo key
product_key = {}  # Dict lồng: ten_san_pham -> ten_hang_hoa -> list[key]

for item in converted_data:
    ten_san_pham = item['ten_san_pham']
    for muc in item['cac_muc']:
        ten_hang_hoa = muc['ten_hang_hoa']
        thong_so_ky_thuat = muc['thong_so_ky_thuat']
        for key, value in thong_so_ky_thuat.items():
            if isinstance(value, list):
                q = value[0]
                k = value[1]
                value_str = ' '.join(value)
            else:
                q = None
                k = value
                value_str = value

            # Ghi vào context_queries
            context_queries[key] = {
                "ten_san_pham": ten_san_pham,
                "ten_hang_hoa": ten_hang_hoa,
                "value": value_str,
                "yeu_cau_ky_thuat_chi_tiet": k,
                "yeu_cau_ky_thuat": q
            }

            # Ghi vào product_key
            if ten_san_pham not in product_key:
                product_key[ten_san_pham] = {}
            if ten_hang_hoa not in product_key[ten_san_pham]:
                product_key[ten_san_pham][ten_hang_hoa] = []
            product_key[ten_san_pham][ten_hang_hoa].append(key)

# %%
context_queries
# Out:
# {'69A25': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Các loại thiết bị, vật tư, phụ kiện phải có nguồn gốc xuất xứ rõ ràng, có chứng nhận chất lượng sản phẩm của nhà sản xuất.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Các loại thiết bị, vật tư, phụ kiện phải có nguồn gốc xuất xứ rõ ràng, có chứng nhận chất lượng sản phẩm của nhà sản xuất.',
#   'yeu_cau_ky_thuat': None},
#  '071A1': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thiết bị mới 100% chưa qua sử dụng',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị mới 100% chưa qua sử dụng',
#   'yeu_cau_ky_thuat': None},
#  'BEAC1': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#   'yeu_cau_ky_thuat': None},
#  '19489': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#   'yeu_cau_ky_thuat': None},
#  '80D06': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#   'yeu_cau_ky_thuat': None},
#  '3156F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#   'yeu_cau_ky_thuat': None},
#  '140CB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#   'yeu_cau_ky_thuat': None},
#  'E5887': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#   'yeu_cau_ky_thuat_chi_tiet': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#   'yeu_cau_ky_thuat': None},
#  '477EB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat_chi_tiet': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat': None},
#  '48C02': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#   'yeu_cau_ky_thuat_chi_tiet': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#   'yeu_cau_ky_thuat': None},
#  'AE97F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#   'yeu_cau_ky_thuat_chi_tiet': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#   'yeu_cau_ky_thuat': None},
#  '7B62B': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#   'yeu_cau_ky_thuat': None},
#  '76695': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#   'yeu_cau_ky_thuat': None},
#  'DC333': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.',
#   'yeu_cau_ky_thuat': None},
#  '84BCD': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Có tính năng chống sét',
#   'yeu_cau_ky_thuat_chi_tiet': 'Có tính năng chống sét',
#   'yeu_cau_ky_thuat': None},
#  '70354': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Điện áp đầu ra danh định -48VDC, cực dương đấu đất',
#   'yeu_cau_ky_thuat_chi_tiet': 'Điện áp đầu ra danh định -48VDC, cực dương đấu đất',
#   'yeu_cau_ky_thuat': None},
#  'B6CD3': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC',
#   'yeu_cau_ky_thuat': None},
#  '060AE': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Độ ổn định điện áp đầu ra: ≤1%',
#   'yeu_cau_ky_thuat_chi_tiet': 'Độ ổn định điện áp đầu ra: ≤1%',
#   'yeu_cau_ky_thuat': None},
#  '7559A': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#   'yeu_cau_ky_thuat_chi_tiet': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#   'yeu_cau_ky_thuat': None},
#  '57408': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#   'yeu_cau_ky_thuat_chi_tiet': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#   'yeu_cau_ky_thuat': None},
#  'C4531': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat_chi_tiet': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat': None},
#  '67B0A': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Hệ số công suất (power factor) của Rectifier: ≥0.99 với tải từ 50÷100%',
#   'yeu_cau_ky_thuat_chi_tiet': 'Hệ số công suất (power factor) của Rectifier: ≥0.99 với tải từ 50÷100%',
#   'yeu_cau_ky_thuat': None},
#  '11499': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Hiệu suất đỉnh (peak efficiency) module rectifier: ≥ 0,95',
#   'yeu_cau_ky_thuat_chi_tiet': 'Hiệu suất đỉnh (peak efficiency) module rectifier: ≥ 0,95',
#   'yeu_cau_ky_thuat': None},
#  'A1F38': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Tổng độ méo hài THD của Rectifier: ≤5% với tải từ 50÷100% tại điện áp 220VAC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tổng độ méo hài THD của Rectifier: ≤5% với tải từ 50÷100% tại điện áp 220VAC',
#   'yeu_cau_ky_thuat': None},
#  'FA3B9': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Rectifier thay thế nóng được khi tủ nguồn đang hoạt động.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Rectifier thay thế nóng được khi tủ nguồn đang hoạt động.',
#   'yeu_cau_ky_thuat': None},
#  '81515': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Rectifier hoạt động theo cơ chế chia tải',
#   'yeu_cau_ky_thuat_chi_tiet': 'Rectifier hoạt động theo cơ chế chia tải',
#   'yeu_cau_ky_thuat': None},
#  '604AA': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Trạng thái hoạt động của Rectifier được hiển thị bằng đèn LED.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Trạng thái hoạt động của Rectifier được hiển thị bằng đèn LED.',
#   'yeu_cau_ky_thuat': None},
#  '50659': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu với module chỉnh lưu (Rectifier)',
#   'value': 'Có khả năng đặt tốc độ quạt theo chế độ tự động hoặc full tốc độ.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Có khả năng đặt tốc độ quạt theo chế độ tự động hoặc full tốc độ.',
#   'yeu_cau_ky_thuat': None},
#  '26D8D': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#   'value': 'Bộ nguồn có chức năng cấp nguồn DC cho thiết bị và nạp cho acquy ở các chế độ nạp đệm và nạp bổ sung. Quá trình nạp phải được chuyển tự động giữa các chế độ. Bộ nguồn sử dụng công nghệ chuyển mạch (switch mode).',
#   'yeu_cau_ky_thuat_chi_tiet': 'Bộ nguồn có chức năng cấp nguồn DC cho thiết bị và nạp cho acquy ở các chế độ nạp đệm và nạp bổ sung. Quá trình nạp phải được chuyển tự động giữa các chế độ. Bộ nguồn sử dụng công nghệ chuyển mạch (switch mode).',
#   'yeu_cau_ky_thuat': None},
#  '927A0': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#   'value': 'Bộ nguồn phải tự động chuyển đổi đường cấp nguồn cho phụ tải khi điện áp AC vào bộ nguồn bị ngắt từ bộ nắn nạp sang nguồn dự phòng nóng acquy mà không có sự gián đoạn nào. Sau khi việc cấp điện AC được phục hồi thì bộ thiết bị điều khiển phải đảm bảo tự động chuyển đổi lại trạng thái làm việc ban đầu và cũng không có sự gián đoạn nào.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Bộ nguồn phải tự động chuyển đổi đường cấp nguồn cho phụ tải khi điện áp AC vào bộ nguồn bị ngắt từ bộ nắn nạp sang nguồn dự phòng nóng acquy mà không có sự gián đoạn nào. Sau khi việc cấp điện AC được phục hồi thì bộ thiết bị điều khiển phải đảm bảo tự động chuyển đổi lại trạng thái làm việc ban đầu và cũng không có sự gián đoạn nào.',
#   'yeu_cau_ky_thuat': None},
#  '3A2AF': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#   'value': 'Hệ thống có trang bị chức năng LLVD (Load Low Voltage Disconection).',
#   'yeu_cau_ky_thuat_chi_tiet': 'Hệ thống có trang bị chức năng LLVD (Load Low Voltage Disconection).',
#   'yeu_cau_ky_thuat': None},
#  '32FAA': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#   'value': 'Phải giám sát được hoạt động của hệ thống nguồn từ xa qua cổng Ethernet (web pages/ SNMP).',
#   'yeu_cau_ky_thuat_chi_tiet': 'Phải giám sát được hoạt động của hệ thống nguồn từ xa qua cổng Ethernet (web pages/ SNMP).',
#   'yeu_cau_ky_thuat': None},
#  'B279E': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#   'value': 'Phải có mạch bảo vệ lắp sẵn trong tủ nguồn để chống lại hiện tượng quá điện áp, quá tải và dòng ngắn mạch, bảo vệ acquy không cho phóng điện khi điện áp quá thấp.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Phải có mạch bảo vệ lắp sẵn trong tủ nguồn để chống lại hiện tượng quá điện áp, quá tải và dòng ngắn mạch, bảo vệ acquy không cho phóng điện khi điện áp quá thấp.',
#   'yeu_cau_ky_thuat': None},
#  'B23B7': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#   'value': 'Hệ thống nguồn phải có tiếp đất, chống sét',
#   'yeu_cau_ky_thuat_chi_tiet': 'Hệ thống nguồn phải có tiếp đất, chống sét',
#   'yeu_cau_ky_thuat': None},
#  '2DEA0': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Tính năng của thiết bị nguồn',
#   'value': 'Tính năng cảnh báo: bao gồm tối thiểu nhưng không giới hạn khả năng xuất cảnh báo như: ●  Lỗi AC đầu vào của Rectifier ●  Lỗi quá nhiệt của Rectifier ●  Lỗi quạt của Rectifier ●  Lỗi của Rectifier ●  Mất điện AC ●  Cảnh báo AC đầu vào thấp ●  Cảnh báo AC đầu vào cao ●  Cảnh báo DC cao ●  Cảnh báo DC thấp ●  Cảnh báo LVD ●  Cảnh báo dòng sạc Ắc quy cao',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tính năng cảnh báo: bao gồm tối thiểu nhưng không giới hạn khả năng xuất cảnh báo như: ●  Lỗi AC đầu vào của Rectifier ●  Lỗi quá nhiệt của Rectifier ●  Lỗi quạt của Rectifier ●  Lỗi của Rectifier ●  Mất điện AC ●  Cảnh báo AC đầu vào thấp ●  Cảnh báo AC đầu vào cao ●  Cảnh báo DC cao ●  Cảnh báo DC thấp ●  Cảnh báo LVD ●  Cảnh báo dòng sạc Ắc quy cao',
#   'yeu_cau_ky_thuat': None},
#  '6F7C6': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#   'value': 'Hiển thị bằng màn hình LCD, có khả năng hiển thị các thông số điện áp (U), dòng điện (I) và một số thông số khác như: cảnh báo, hiển thị chế độ nạp acquy.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Hiển thị bằng màn hình LCD, có khả năng hiển thị các thông số điện áp (U), dòng điện (I) và một số thông số khác như: cảnh báo, hiển thị chế độ nạp acquy.',
#   'yeu_cau_ky_thuat': None},
#  '12F66': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#   'value': 'Bảng điều khiển phải gồm có nút điều khiển để thiết lập và điều chỉnh các thông số, màn hình hiển thị các thông số vận hành, đèn chỉ thị trạng thái, các cổng truy cập và giám sát từ xa.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Bảng điều khiển phải gồm có nút điều khiển để thiết lập và điều chỉnh các thông số, màn hình hiển thị các thông số vận hành, đèn chỉ thị trạng thái, các cổng truy cập và giám sát từ xa.',
#   'yeu_cau_ky_thuat': None},
#  'C65FF': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#   'value': 'Cổng kết nối: RS485, Ethernet, USB',
#   'yeu_cau_ky_thuat_chi_tiet': 'Cổng kết nối: RS485, Ethernet, USB',
#   'yeu_cau_ky_thuat': None},
#  '64DF6': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#   'value': 'Giao thức kết nối: IPv4, HTTPS, SNMP V2/V3',
#   'yeu_cau_ky_thuat_chi_tiet': 'Giao thức kết nối: IPv4, HTTPS, SNMP V2/V3',
#   'yeu_cau_ky_thuat': None},
#  '4C891': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#   'value': 'Sử dụng màn hình LCD màu',
#   'yeu_cau_ky_thuat_chi_tiet': 'Sử dụng màn hình LCD màu',
#   'yeu_cau_ky_thuat': None},
#  '46E2F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#   'value': 'Cho phép cài đặt, thiết lập các thông số cho thiết bị nguồn.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Cho phép cài đặt, thiết lập các thông số cho thiết bị nguồn.',
#   'yeu_cau_ky_thuat': None},
#  '34694': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Khối điều khiển và hiển thị',
#   'value': 'Bảng điều khiển được đặt trước mặt máy, dễ quan sát.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Bảng điều khiển được đặt trước mặt máy, dễ quan sát.',
#   'yeu_cau_ky_thuat': None},
#  'D0F05': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Điều kiện làm việc',
#   'value': '●  Dải nhiệt độ từ -10°C đến +60°C ●  Dải độ ẩm từ 5% đến 95%',
#   'yeu_cau_ky_thuat_chi_tiet': '●  Dải nhiệt độ từ -10°C đến +60°C ●  Dải độ ẩm từ 5% đến 95%',
#   'yeu_cau_ky_thuat': None},
#  'CC15E': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Hệ thống làm mát',
#   'value': 'Làm mát bằng quạt',
#   'yeu_cau_ky_thuat_chi_tiet': 'Làm mát bằng quạt',
#   'yeu_cau_ky_thuat': None},
#  'A534E': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Điều kiện bảo hành',
#   'value': 'Có cơ sở bảo hành chính hãng thiết bị nguồn tại Việt Nam.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Có cơ sở bảo hành chính hãng thiết bị nguồn tại Việt Nam.',
#   'yeu_cau_ky_thuat': None},
#  'FF244': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': '02 dàn Ac quy 12V - 200Ah (08 bình):',
#   'yeu_cau_ky_thuat_chi_tiet': '02 dàn Ac quy 12V - 200Ah (08 bình):',
#   'yeu_cau_ky_thuat': None},
#  'CEBE4': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Ắcquy phải là loại Axít chì, vỏ bình kín không phải bảo dưỡng (loại VLRA) và không ảnh hưởng đến môi trường, cho phép bố trí chung trong phòng máy với các thiết bị điện khác, chất liệu vỏ bình acquy là nhựa ABS.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Ắcquy phải là loại Axít chì, vỏ bình kín không phải bảo dưỡng (loại VLRA) và không ảnh hưởng đến môi trường, cho phép bố trí chung trong phòng máy với các thiết bị điện khác, chất liệu vỏ bình acquy là nhựa ABS.',
#   'yeu_cau_ky_thuat': None},
#  'ECC21': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Thời hạn sản xuất acquy không quá 1 năm tính từ ngày cấp hàng.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thời hạn sản xuất acquy không quá 1 năm tính từ ngày cấp hàng.',
#   'yeu_cau_ky_thuat': None},
#  '49AD6': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Điện áp nạp ở 25oC: + Chế độ nạp đệm (Float mode): 2.25V/cell hoặc 13.6V/bình + Chế độ nạp bổ sung (Boost mode): 2.35-2.4V/cell hoặc 14.4V/bình',
#   'yeu_cau_ky_thuat_chi_tiet': 'Điện áp nạp ở 25oC: + Chế độ nạp đệm (Float mode): 2.25V/cell hoặc 13.6V/bình + Chế độ nạp bổ sung (Boost mode): 2.35-2.4V/cell hoặc 14.4V/bình',
#   'yeu_cau_ky_thuat': None},
#  '0A99A': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Độ tự xả sau 03 tháng: dung lượng ắcquy ≥ 90% dung lượng danh định',
#   'yeu_cau_ky_thuat_chi_tiet': 'Độ tự xả sau 03 tháng: dung lượng ắcquy ≥ 90% dung lượng danh định',
#   'yeu_cau_ky_thuat': None},
#  'A5FB0': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Đầu cực: dạng M6 hoặc M8',
#   'yeu_cau_ky_thuat_chi_tiet': 'Đầu cực: dạng M6 hoặc M8',
#   'yeu_cau_ky_thuat': None},
#  '39D1A': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Quy cách dàn ắcquy: + Mỗi dàn ắcquy gồm 4 bình. + Điện áp danh định mỗi bình là 12VDC. + Điện áp cả tổ là 48VDC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Quy cách dàn ắcquy: + Mỗi dàn ắcquy gồm 4 bình. + Điện áp danh định mỗi bình là 12VDC. + Điện áp cả tổ là 48VDC',
#   'yeu_cau_ky_thuat': None},
#  'A8053': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Dung lượng dàn ắcquy≥ 200Ah.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dung lượng dàn ắcquy≥ 200Ah.',
#   'yeu_cau_ky_thuat': None},
#  '53371': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Nội trở ≤ 4.5mΩ',
#   'yeu_cau_ky_thuat_chi_tiet': 'Nội trở ≤ 4.5mΩ',
#   'yeu_cau_ky_thuat': None},
#  '82FFB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Mỗi dàn acquy phải gồm đầy đủ cáp nối giữa các bình',
#   'yeu_cau_ky_thuat_chi_tiet': 'Mỗi dàn acquy phải gồm đầy đủ cáp nối giữa các bình',
#   'yeu_cau_ky_thuat': None},
#  '28EC9': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Acquy kèm theo',
#   'value': 'Kèm phụ kiện lắp đặt (cầu nối giữa các bình, kẹp cực, giá đỡ..)',
#   'yeu_cau_ky_thuat_chi_tiet': 'Kèm phụ kiện lắp đặt (cầu nối giữa các bình, kẹp cực, giá đỡ..)',
#   'yeu_cau_ky_thuat': None}}

# %%
product_key
# Out:
# {'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)': {'Yêu cầu chung': ['69A25',
#    '071A1',
#    'BEAC1',
#    '19489',
#    '80D06',
#    '3156F',
#    '140CB'],
#   'Cấu hình thiết bị nguồn': ['E5887', '477EB', '48C02', 'AE97F'],
#   'Đầu vào AC': ['7B62B', '76695', 'DC333', '84BCD'],
#   'Đầu ra DC': ['70354', 'B6CD3', '060AE', '7559A', '57408'],
#   'Yêu cầu với module chỉnh lưu (Rectifier)': ['C4531',
#    '67B0A',
#    '11499',
#    'A1F38',
#    'FA3B9',
#    '81515',
#    '604AA',
#    '50659'],
#   'Tính năng của thiết bị nguồn': ['26D8D',
#    '927A0',
#    '3A2AF',
#    '32FAA',
#    'B279E',
#    'B23B7',
#    '2DEA0'],
#   'Khối điều khiển và hiển thị': ['6F7C6',
#    '12F66',
#    'C65FF',
#    '64DF6',
#    '4C891',
#    '46E2F',
#    '34694'],
#   'Điều kiện làm việc': ['D0F05'],
#   'Hệ thống làm mát': ['CC15E'],
#   'Điều kiện bảo hành': ['A534E'],
#   'Acquy kèm theo': ['FF244',
#    'CEBE4',
#    'ECC21',
#    '49AD6',
#    '0A99A',
#    'A5FB0',
#    '39D1A',
#    'A8053',
#    '53371',
#    '82FFB',
#    '28EC9']}}

# %%
# Lưu với tên file mặc định
with open('context_prompts.json', 'w', encoding='utf-8') as f:
    json.dump(context_prompts, f, ensure_ascii=False, indent=2)

print(f"✅ Đã lưu {len(context_prompts)} context prompts vào file: context_prompts.json")

# %%
from openai import OpenAI
from dotenv import load_dotenv
import re
import os
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
test = dict(list(context_queries.items())[1:20])
test
# Out:
# {'071A1': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thiết bị mới 100% chưa qua sử dụng',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị mới 100% chưa qua sử dụng',
#   'yeu_cau_ky_thuat': None},
#  'BEAC1': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#   'yeu_cau_ky_thuat': None},
#  '19489': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#   'yeu_cau_ky_thuat': None},
#  '80D06': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#   'yeu_cau_ky_thuat': None},
#  '3156F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#   'yeu_cau_ky_thuat': None},
#  '140CB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#   'yeu_cau_ky_thuat': None},
#  'E5887': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#   'yeu_cau_ky_thuat_chi_tiet': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#   'yeu_cau_ky_thuat': None},
#  '477EB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat_chi_tiet': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat': None},
#  '48C02': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#   'yeu_cau_ky_thuat_chi_tiet': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#   'yeu_cau_ky_thuat': None},
#  'AE97F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#   'yeu_cau_ky_thuat_chi_tiet': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#   'yeu_cau_ky_thuat': None},
#  '7B62B': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#   'yeu_cau_ky_thuat': None},
#  '76695': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#   'yeu_cau_ky_thuat': None},
#  'DC333': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.',
#   'yeu_cau_ky_thuat': None},
#  '84BCD': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Có tính năng chống sét',
#   'yeu_cau_ky_thuat_chi_tiet': 'Có tính năng chống sét',
#   'yeu_cau_ky_thuat': None},
#  '70354': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Điện áp đầu ra danh định -48VDC, cực dương đấu đất',
#   'yeu_cau_ky_thuat_chi_tiet': 'Điện áp đầu ra danh định -48VDC, cực dương đấu đất',
#   'yeu_cau_ky_thuat': None},
#  'B6CD3': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC',
#   'yeu_cau_ky_thuat': None},
#  '060AE': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Độ ổn định điện áp đầu ra: ≤1%',
#   'yeu_cau_ky_thuat_chi_tiet': 'Độ ổn định điện áp đầu ra: ≤1%',
#   'yeu_cau_ky_thuat': None},
#  '7559A': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#   'yeu_cau_ky_thuat_chi_tiet': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#   'yeu_cau_ky_thuat': None},
#  '57408': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#   'yeu_cau_ky_thuat_chi_tiet': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#   'yeu_cau_ky_thuat': None}}

# %%
test, product_key
# Out:
# ({'071A1': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Yêu cầu chung',
#    'value': 'Thiết bị mới 100% chưa qua sử dụng',
#    'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị mới 100% chưa qua sử dụng',
#    'yeu_cau_ky_thuat': None},
#   'BEAC1': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Yêu cầu chung',
#    'value': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#    'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#    'yeu_cau_ky_thuat': None},
#   '19489': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Yêu cầu chung',
#    'value': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#    'yeu_cau_ky_thuat_chi_tiet': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#    'yeu_cau_ky_thuat': None},
#   '80D06': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Yêu cầu chung',
#    'value': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#    'yeu_cau_ky_thuat_chi_tiet': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#    'yeu_cau_ky_thuat': None},
#   '3156F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Yêu cầu chung',
#    'value': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#    'yeu_cau_ky_thuat_chi_tiet': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#    'yeu_cau_ky_thuat': None},
#   '140CB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Yêu cầu chung',
#    'value': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#    'yeu_cau_ky_thuat_chi_tiet': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#    'yeu_cau_ky_thuat': None},
#   'E5887': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#    'value': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#    'yeu_cau_ky_thuat_chi_tiet': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#    'yeu_cau_ky_thuat': None},
#   '477EB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#    'value': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#    'yeu_cau_ky_thuat_chi_tiet': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#    'yeu_cau_ky_thuat': None},
#   '48C02': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#    'value': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#    'yeu_cau_ky_thuat_chi_tiet': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#    'yeu_cau_ky_thuat': None},
#   'AE97F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#    'value': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#    'yeu_cau_ky_thuat_chi_tiet': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#    'yeu_cau_ky_thuat': None},
#   '7B62B': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu vào AC',
#    'value': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#    'yeu_cau_ky_thuat_chi_tiet': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#    'yeu_cau_ky_thuat': None},
#   '76695': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu vào AC',
#    'value': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#    'yeu_cau_ky_thuat_chi_tiet': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#    'yeu_cau_ky_thuat': None},
#   'DC333': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu vào AC',
#    'value': 'Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.',
#    'yeu_cau_ky_thuat_chi_tiet': 'Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.',
#    'yeu_cau_ky_thuat': None},
#   '84BCD': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu vào AC',
#    'value': 'Có tính năng chống sét',
#    'yeu_cau_ky_thuat_chi_tiet': 'Có tính năng chống sét',
#    'yeu_cau_ky_thuat': None},
#   '70354': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu ra DC',
#    'value': 'Điện áp đầu ra danh định -48VDC, cực dương đấu đất',
#    'yeu_cau_ky_thuat_chi_tiet': 'Điện áp đầu ra danh định -48VDC, cực dương đấu đất',
#    'yeu_cau_ky_thuat': None},
#   'B6CD3': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu ra DC',
#    'value': 'Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC',
#    'yeu_cau_ky_thuat_chi_tiet': 'Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC',
#    'yeu_cau_ky_thuat': None},
#   '060AE': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu ra DC',
#    'value': 'Độ ổn định điện áp đầu ra: ≤1%',
#    'yeu_cau_ky_thuat_chi_tiet': 'Độ ổn định điện áp đầu ra: ≤1%',
#    'yeu_cau_ky_thuat': None},
#   '7559A': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu ra DC',
#    'value': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#    'yeu_cau_ky_thuat_chi_tiet': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#    'yeu_cau_ky_thuat': None},
#   '57408': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#    'ten_hang_hoa': 'Đầu ra DC',
#    'value': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#    'yeu_cau_ky_thuat_chi_tiet': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#    'yeu_cau_ky_thuat': None}},
#  {'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)': {'Yêu cầu chung': ['69A25',
#     '071A1',
#     'BEAC1',
#     '19489',
#     '80D06',
#     '3156F',
#     '140CB'],
#    'Cấu hình thiết bị nguồn': ['E5887', '477EB', '48C02', 'AE97F'],
#    'Đầu vào AC': ['7B62B', '76695', 'DC333', '84BCD'],
#    'Đầu ra DC': ['70354', 'B6CD3', '060AE', '7559A', '57408'],
#    'Yêu cầu với module chỉnh lưu (Rectifier)': ['C4531',
#     '67B0A',
#     '11499',
#     'A1F38',
#     'FA3B9',
#     '81515',
#     '604AA',
#     '50659'],
#    'Tính năng của thiết bị nguồn': ['26D8D',
#     '927A0',
#     '3A2AF',
#     '32FAA',
#     'B279E',
#     'B23B7',
#     '2DEA0'],
#    'Khối điều khiển và hiển thị': ['6F7C6',
#     '12F66',
#     'C65FF',
#     '64DF6',
#     '4C891',
#     '46E2F',
#     '34694'],
#    'Điều kiện làm việc': ['D0F05'],
#    'Hệ thống làm mát': ['CC15E'],
#    'Điều kiện bảo hành': ['A534E'],
#    'Acquy kèm theo': ['FF244',
#     'CEBE4',
#     'ECC21',
#     '49AD6',
#     '0A99A',
#     'A5FB0',
#     '39D1A',
#     'A8053',
#     '53371',
#     '82FFB',
#     '28EC9']}})

# %%
import os
from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex
from llama_index.core.vector_stores import VectorStoreInfo
from llama_index.vector_stores.qdrant import QdrantVectorStore
from qdrant_client import QdrantClient, AsyncQdrantClient
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core.retrievers import VectorIndexAutoRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.settings import Settings
from llama_index.core.vector_stores import (
    MetadataFilter,
    MetadataFilters,
    FilterOperator,
    FilterCondition
)
import time


# Cấu hình LLM và Embedding
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")
Settings.llm = OpenAI(model="gpt-4o-mini")
# Cấu hình client Qdrant
client = QdrantClient(
    url="https://a8bcf78f-0147-411f-aa58-079f863fcd6d.us-west-1-0.aws.cloud.qdrant.io:6333",
    api_key=os.getenv("QDRANT_API_KEY"),
)
aclient = AsyncQdrantClient(
    url="https://a8bcf78f-0147-411f-aa58-079f863fcd6d.us-west-1-0.aws.cloud.qdrant.io:6333",
    api_key=os.getenv("QDRANT_API_KEY"),
)
# Khởi tạo Vector Store
vector_store = QdrantVectorStore(
    collection_name="hello_my_friend",
    client=client,
    aclient=aclient,
)

def retrieve_document(product_line, query_str):
    product_ids = []
    index = VectorStoreIndex.from_vector_store(vector_store=vector_store)
    
    filters_document = MetadataFilters(
        filters=[
            MetadataFilter(key="product_line", operator=FilterOperator.EQ, value=product_line),
            MetadataFilter(key="type", operator=FilterOperator.EQ, value="summary_document"),
        ],
    condition=FilterCondition.AND,
    )
    retriever_document = index.as_retriever(similarity_top_k=5, sparse_top_k=10, verbose=True, enable_hybrid=True, filters=filters_document)
    
    results = retriever_document.retrieve(query_str)
    # print("product: ", results)
    # print("results: ", results)
    for result in results:
        metadata = result.metadata
        product_ids.append(metadata["product_id"])

    return product_ids

def retrieve_chunk(product_ids, query_str):
    index = VectorStoreIndex.from_vector_store(vector_store=vector_store)
    
    filters_chunk = MetadataFilters(
        filters=[
            MetadataFilter(key="product_id", operator=FilterOperator.IN, value=product_ids),
            MetadataFilter(key="type", operator=FilterOperator.EQ, value="chunk_document"),
        ],
        condition=FilterCondition.AND,
    )

    retriever_chunk = index.as_retriever(similarity_top_k=5, verbose=True, filters=filters_chunk)
    
    results = retriever_chunk.retrieve(query_str)
    print("chunk : ", results)
    content = ""
    for i, result in enumerate(results, start=1):
        metadata = result.metadata
        file_name = metadata["file_name"]+ ".pdf"
        page = metadata["page"]
        table = metadata["table_name"]
        figure_name = metadata.get("figure_name")
        text = result.text.strip()
        content += f"Chunk {i} trong file {file_name} tại trang {page}, có chứa bảng {table} và hình {figure_name} có nội dung:\n{text}\n\n"

    return content

def retrieve_product_line(product_name, assistant_id="asst_j5wHMN84dpSLXD2GMH5QifS0"):
    from openai import OpenAI 
    clientOpenAi = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    thread = clientOpenAi.beta.threads.create()
    thread_id = thread.id
    # 2. Gửi message vào thread
    clientOpenAi.beta.threads.messages.create(
        thread_id=thread_id,
        role="user",
        content=product_name
    )
    run = clientOpenAi.beta.threads.runs.create(
        thread_id=thread_id,
        assistant_id=assistant_id,
        tool_choice="auto"  # hoặc thay bằng tool cụ thể nếu cần
        # tool_choice={"type": "function", "function": {"name": "danh_gia_ky_thuat"}}
    )
    run_id = run.id
    # 4. Đợi assistant xử lý xong
    while True:
        run_status = clientOpenAi.beta.threads.runs.retrieve(thread_id=thread_id, run_id=run_id)
        if run_status.status == "completed":
            break
        elif run_status.status in ["failed", "cancelled", "expired"]:
            raise Exception(f"Run failed with status: {run_status.status}")
        time.sleep(1)

    # 5. Lấy kết quả trả về từ Assistant
    messages = clientOpenAi.beta.threads.messages.list(thread_id=thread_id)
    for message in reversed(messages.data):  # đảo ngược để lấy kết quả mới nhất trước
        if message.role == "assistant":
            for content in message.content:
                if content.type == "text":
                    # print("product_line: ", content.text.value)
                    return content.text.value

    return None

# %%
for product in product_key:
    product_line = retrieve_product_line(product)
    query_str = "Description This is a modular -48V DC power system operating on a 220VAC input, integrating at least three rectifier modules (≥3000W each) and two battery banks of 12V–200Ah (48VDC total per bank). Designed with switch-mode power technology, the system is housed in a fully integrated cabinet, capable of providing continuous DC power and intelligent battery charging. It ensures stable operation for telecom or other critical infrastructure applications. ✅ Features & Benefits High efficiency, hot-swappable modules, automatic load sharing, PF ≥0.99, efficiency ≥95%. Automatic switchover between AC, DC, and battery without power interruption. Stable, low-noise output; voltage range: -43.2VDC to -57.6VDC.Smart battery charging with over-discharge protection; supports 200Ah VRLA batteries.Color LCD display, remote monitoring via SNMP, HTTPS, and web interface.Comprehensive protection: surge, LVD, overload, over-temperature, fan failure.Fan-based cooling; reliable operation from -10°C to +60°C.Fully equipped with accessories; manufacturer-backed warranty in Vietnam ≥12 months."
    
    # items = product_key[product]
    # for key in items:
    #     for item in items[key]:
    #         if item not in test:
    #             continue
    #         query_str += test[item]['value']
    product_ids = retrieve_document(product_line, query_str)
    print(product_ids)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5752\3376383554.py:92: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   thread = clientOpenAi.beta.threads.create()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5752\3376383554.py:95: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   clientOpenAi.beta.threads.messages.create(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5752\3376383554.py:100: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   run = clientOpenAi.beta.threads.runs.create(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5752\3376383554.py:109: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   run_status = clientOpenAi.beta.threads.runs.retrieve(thread_id=thread_id, run_id=run_id)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5752\3376383554.py:117: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   messages = clientOpenAi.beta.threads.messages.list(thread_id=thread_id)
# ['4938c279-7371-11f0-9a31-38f3abb08dd1', '74730619-7368-11f0-9fa1-38f3abb08dd1', 'ef875c94-7371-11f0-a926-38f3abb08dd1', 'a34a2f4f-7368-11f0-a85b-38f3abb08dd1', 'd2a47434-736b-11f0-b609-38f3abb08dd1']

# %%
for key in items:
    for item in items[key]:
        if item not in test:
            continue
        query = test[item]["value"]
        content = retrieve_chunk(product_ids, query)
        test[item]["relevant_context"] = content

# %%
for key in test:
    print(key)
# Out:
# 93C6C
# 8E2C6
# 17415
# D70B1
# ABE44
# B4706
# A09AB
# 9F080
# 5F95F
# FC80B
# 5552C
# 3513E
# 0C362
# 80D4F
# 6D7D8
# 3323F
# 97B78
# 070AF
# 1F101

# %%
test
# Out:
# {'93C6C': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thiết bị mới 100% chưa qua sử dụng',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị mới 100% chưa qua sử dụng',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file Netsure 731 A41 Usermanual.pdf tại trang 21, có chứa bảng None và hình None có nội dung:\n## 3.1 Installation Check and Startup\n\nBefore the test, inform the chief manufacturer representative. Only trained electrical engineer can maintain and operate this equipment. In operation, the installation personnel are not allowed to wear conductive objects such as watches, bracelets, bangles and rings.\n\nDuring operation, parts of this equipment carry hazardous voltage. Misoperation may result in severe or fatal injuries and property damage. Before the test, check the equipment to ensure the proper earthing. Installation check must be done before testing. Then the batteries can be charged for the first time.\n\nMake sure that the AC input MCBs, battery MCBs and load MCBs are switched off. Make sure that all the devices are properly installed.\n\nChunk 2 trong file Netsure 2100 series User Manual.pdf tại trang 4, có chứa bảng Startup Preparations and Startup Check Items và hình None có nội dung:\n## 3.1 Testing Distribution Unit And Rectifiers\n\n🕮 Note\nBefore the test, inform the chief manufacturer representative. Only trained electrical engineer can maintain and operate this equipment. In operation, the installation personnel are not allowed to wear conductive objects such as watches, bracelets, bangles and rings.\n\nDuring operation, parts of this equipment carry hazardous voltage. Wrong operation may result in severe or fatal injuries and property damage. Before the test, Installation check must be done before testing. Then the batteries can be charged for the first time.\n\nMake sure that the upstream AC output MCBs and load MCBs inside the subrack are switched off. Make sure that all the devices are properly installed.\n\nPlease check the power system according to below listed items.\n\nStartup preparations\n\n| Check item                                                                                                                                                                                                                                                      | OK | Remark  |\n| --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | -- | ------- |\n| Make sure that all the MCBs are switched off.                                                                                                                                                                                                                   | ☐  |         |\n| Measure the AC input voltage. Make sure the input voltage is within the allowable range.                                                                                                                                                                        | ☐  | Umin= V |\n| Make sure that the communication and dry contact alarm output cable are connected to the monitoring board                                                                                                                                                       | ☐  |         |\n| Make sure that the temperature sensor is installed correctly                                                                                                                                                                                                    | ☐  |         |\n| Use a voltmeter to measure the battery string voltage and make sure the battery polarities are correct                                                                                                                                                          | ☐  | Umin= V |\n| Check with an ohmmeter that there is no short circuit between the positive & negative terminal of DC output, between the positive & negative battery poles or AC input terminals (Note ...
#  '8E2C6': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thiết bị phải được sản xuất từ năm 2021 trở lại đây',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': "Chunk 1 trong file netsure-2100-brochure.pdf tại trang 2, có chứa bảng Technical Specifications of NETSURE™ 2100 A31-S2 and A31-S3 và hình None có nội dung:\nNOTES\n*) Battery MCB configuration can be changed on demand at factory, available sizes are 32A, 40A and 50A\n**) Load MCB configuration can be changed on demand at factory, available sizes are 3A, 6A, 10A, 16A, 20A, 25A and 30A\n\nVertivCo.com | Vertiv Infrastructure Limited, George Curl Way, Southampton, SO18 2RY, VAT Number: GB188146827\n\n© 2018 Vertiv Co. All rights reserved. Vertiv™, the Vertiv logo, NetSure™ Advanced Remote Distribution Cabinet and NetSure Control Unit (NCU) are trademarks or registered trademarks of Vertiv Co. All other names and logos referred to are trade names, trademarks or registered trademarks of their respective owners. While every precaution has been taken to ensure accuracy and completeness herein, Vertiv Co. assumes no responsibility, and disclaims all liability, for damages resulting from use of this information or for any errors or omissions. Specifications are subject to change without notice.\n\nNovember 2018\n\nChunk 2 trong file Netsure 731 A41 Usermanual.pdf tại trang 1, có chứa bảng None và hình None có nội dung:\n# System User Manual\n\n资料版本 V1.1\n\nVersion V1.1.\n\n归档日期 2017-10-22\n\nNew product Netsure 731 A41-S8 added\n\nBOM 编码 31013139\n\nRevision date October 22, 2017\n\nBOM 31013139\n\n艾默生网络能源有限公司为客户提供全方位的技术支持，用户可与就近的艾默生网络能源有限公司办事处或客户服务中心联系，也可直接与公司总部联系。\n\n艾默生网络能源有限公司\n\nCopyright © 2017 by Vertiv Co., Ltd.\n\n版权所有，保留一切权利。内容如有改动，恕不另行通知。\n\n艾默生网络能源有限公司\n\nVertiv Co., Ltd.\n\n地址：\n\n深圳市南山区学苑大道 1001 号南山智园 B2 栋\n\nAddress: Block B2, Nanshan I Park, No.1001 Xueyuan Road, Nanshan District, Shenzhen, 518055, P.R.China\n\n邮编：518055\n\n公司网址：Homepage: www.Vertiv.com\n\nwww.Vertivco.com\n\n客户服务热线：4008876510\n\nE-mail：Service@vertivco.com\n\n\n\n\n\nNO_CONTENT_HERE\n\nChunk 3 trong file netsure-701-series_datasheet_en-asia.pdf tại trang 2, có chứa bảng DC Distribution Specifications và hình None có nội dung:\n## DC Distribution\n\n| Unit                               | Specifications                                                                                                                               |\n| ---------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------- |\n| Low Ohmic Distribution Unit (LOD)  | • Dimensions: 132.5 (H) × 584 (W) × 250 (D)<br/>• Up to 28 pcs MCBs rated from 6-125 A                                                       |\n| High Ohmic Distribution Unit (HOD) | • Dimensions: 132.5 (H) × 584 (W) × 250 (D)<br/>• Up to 35 pcs 16A MCBs<br/>• Each MCB is connected to a 40m resistor                        |\n| Fuse Unit                          | • Dimensions: 427 (H) × 584 (W) × 354 (D)<br/>• Up to 6 NT2, NT3 fuses rated from 160 – 630 A or<br/>up to 11 NT00 fuses rated from 6 - 160A |\n| Battery / Load Connection Unit     | • Dimensions: 383.5 (H) × 554 (W) × 190 (D)<br/>• Up to 4 pcs NT4 fuses rated from 800 – 1250 A<br/>• Battery / Load fuses: 1 – 4            |\n\n\nVertivCo.com |\n\n© 2017 Vertiv Co. All rights reserved. Vertiv and the Vertiv logo are trademarks or registered trademarks of Vertiv Co. All other names and logos referred to are trade names, trademarks or registered trademarks of their respective owners. While every precaution has been taken to ensure accuracy and completeness herein, Vertiv Co. assumes no responsibility, and disclaims all liability, for damages resulting from use of this information or for any errors or omissions. Specifications are subject to change without notice.\n\nChunk 4 trong file netsure-801-brochure.pdf tại trang 2, có chứa bảng Power Solutions Overview và hình Vertiv Service Diagram có nội dung:\nPk1hbmFnZW1lbnQ8L3RleHQ+PC9zdmc+) |   |\n| --------------------------------------------------------------------------------------- ...
#  '17415': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tuân thủ tiêu chuẩn IEC 60950-1',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file netsure-801-brochure.pdf tại trang 4, có chứa bảng Safety & Standard Compliance và hình None có nội dung:\n### Safety & standard compliance\n\n| Electrical    | IEC 60950-1, EN 60950-1, UL 60950-1            |\n| ------------- | ---------------------------------------------- |\n| EMC           | EN 300 386, 2001 Class B, FCC Part 15, Class B |\n| Environmental | CE; NEBS Level 3                               |\n\nChunk 2 trong file Netsure 731 A41 Usermanual.pdf tại trang 30, có chứa bảng Technical and Engineering Data và hình None có nội dung:\nConfigurable through controller), the rectifier will shut off and hold that state. It requires manual resetting to restore the operation<br/>Manual resetting: Resetting can be done manually through the controller, or by removing the rectifier from system |                                                                                                                                                                                                                                                                                                  |\n|                                |                                         | Temperature power limiting                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | The rectifiercan start in -40℃;<br/>Below 45℃, the rectifier with full power (3000 W) output.<br/>From 45℃\\~55℃, the rectifier with linearly derating to 2900W.<br/>From 55℃\\~65℃, the rectifier with linearly derating to 2250W.<br/>From 65℃\\~70℃, the rectifier with linearly derating to 0W. |\n|                                | EMC                                     | Conducted emission                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   | Class B EN55022                                                                                                                                                                            ...
#  'D70B1': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file netsure-701-series_datasheet_en-asia.pdf tại trang 2, có chứa bảng Controller Module-M830D Specifications và hình None có nội dung:\n## Controller Module-M830D\n\n| Display                 | 320 x 240 Pixels TFT LCD                                                                                                                                              |\n| ----------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------- |\n| Communication Interface | RS 232, Rs485, Ethernet, USB                                                                                                                                          |\n| Protocol                | IPv4, IPv6, HTTPS, SNMP V2/V3, EEM, SocTpe, Rsoc, Modbus                                                                                                              |\n| Input                   | **Analog:** 3 temperatures, 2 battery currents, 1 load current, 1 bus voltage, 2 battery voltages, 1 fuel level sensor and much more with additional interface boards |\n|                         | **Digital:** 1 input for status of surge protective device auxiliary contacts, 12 load fuses, 6 battery fuses, bi-stable contactor status                             |\n| Protocol                | 3 LVD mono & bistable contactors                                                                                                                                      |\n| Key Features            | • Menu operated and user friendly<br/>• Intelligent battery management<br/>• Stores up to 4000 alarm history logs<br/>• Energy saving and Power split function        |\n\nChunk 2 trong file netsure-801-brochure.pdf tại trang 4, có chứa bảng Power Supply Specifications và hình None có nội dung:\n### General\n\n| Power Supply               | 19VDC to 60VDC |\n| -------------------------- | -------------- |\n| Power consumption, Maximum | 18W            |\n\nChunk 3 trong file netsure-212-c23-datasheet2.pdf tại trang 2, có chứa bảng NetSure™ 212 C23 System Technical Parameters và hình None có nội dung:\n## NetSure™ 212 C23 system technical parameters\n\n| System distribution | Description                                 |\n| ------------------- | ------------------------------------------- |\n| Power supply mode   | Single-phase and three-line                 |\n| Battery fuses       | 30A x 1                                     |\n| Output branch       | 10A x 4, 20A x 2 (Battery Protection, fuse) |\n\n\n| Input paramters       |                            |\n| --------------------- | -------------------------- |\n| Input voltage range   | 80 -300Vac (Phase voltage) |\n| Input frequency range | 45-65Hz                    |\n| Power factor          | ≥0.99                      |\n\n\n| Output paramters |                     |\n| ---------------- | ------------------- |\n| Output voltage   | -42 to -58Vdc       |\n| Output current   | 0 -40A (40A\\@48Vdc) |\n| Rated efficiency | ≥92%                |\n\n\n| Module congifuration |                                                  |\n| -------------------- | ------------------------------------------------ |\n| Control Module       | M225S                                            |\n| Rectifier Module     | R48-1000A / R48-500A (2 as a full configuration) |\n\n\nR48-1000A\n\nM225S\n\nChunk 4 trong file netsure-801-brochure.pdf tại trang 5, có chứa bảng Input Parameters và hình None có nội dung:\n### Input Parameters\n\n| Input Voltage   | 260 \\~ 530Vac          | ![R48-5800e module image]() |\n| --------------- | ---------------------- | --------------------------- |\n| Input Frequency | 45 \\~ 65Hz             |                             |\n| Power Factor    | ≥ 0.99                 |                             |\n| THD             | ≤5% (50% \\~ 110% load) |                             |\n\nChun ...
#  'ABE44': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Tất  cả  các  khối  đặt  trong  tủ  liên  hoàn,  đồng  bộ của  hãng,  tạo  thành  thiết  bị  cấp  nguồn  và  nạp acquyhoàn chỉnh.',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file Netsure 731 A41 Usermanual.pdf tại trang 35, có chứa bảng Packing List of Accessories và hình Figure 5 Accessory showing four components of the battery rack: Accessory 1 (main frame), Accessory 2 (support bar), Accessory 3 (long bar), and Accessory 4 (small bracket) có nội dung:\n### Packing list\n\n![Figure 5 Accessory showing four components of the battery rack: Accessory 1 (main frame), Accessory 2 (support bar), Accessory 3 (long bar), and Accessory 4 (small bracket)]\n\n| Accessory      | Accessory number |\n| -------------- | ---------------- |\n| Accessory 1    | 2                |\n| Accessory 2    | 6                |\n| Accessory 3    | 3                |\n| Accessory 4    | 2                |\n| Expansion bolt | 4 pieces         |\n| Fastener       | 1 set            |\n\nChunk 2 trong file Netsure 731 A41 Usermanual.pdf tại trang 33, có chứa bảng Packing list of accessories for battery racks và hình Accessory có nội dung:\n#### Packing list\n\nFigure 1 Accessory\n\n| Accessory      | Two-layer battery rack | Four-layer battery rack |\n| -------------- | ---------------------- | ----------------------- |\n| Accessory 1    | 2                      | 4                       |\n| Accessory 2    | 8                      | 14                      |\n| Accessory 3    | 2                      | 4                       |\n| Accessory 4    | 2                      | 2                       |\n| Accessory 5    | 0                      | 2                       |\n| Expansion bolt | 4 pieces               | 4 pieces                |\n| Fastener       | 1 set                  | 1 set                   |\n\nChunk 3 trong file Netsure 731 A41 Usermanual.pdf tại trang 34, có chứa bảng None và hình Figure 4 Installation procedure of accessory 2, accessory 4 and accessory 5 có nội dung:\n# Figure 4 Installation procedure of accessory 2, accessory 4 and accessory 5\n\n(a)\n\n(b)\n\nAccessory 4\n\nAccessory 2\n\n\n\n\n\n\n\nAppendix 2    Installation Instruction Of Battery Rack    27\n\nChunk 4 trong file Netsure 731 A41 Usermanual.pdf tại trang 35, có chứa bảng None và hình Figure 7  Installation procedure of accessory 2 and accessory 4 có nội dung:\n### Installation procedures\n\n1. Install accessory 1 and accessory 2 according to Figure 6 (a).\n2. Install accessory 3 according to Figure 6 (b).\n\n![Figure 6 Installation procedure of accessory 1 ~ accessory 3, showing two diagrams (a) and (b) illustrating the assembly process of the battery rack]\n\nNetSure 731 A41 Subrack Power System    User Manual\n\n\n\n\n\n28    Appendix 2  Installation Instruction Of Battery Rack\n\n3. Install accessory 2 and accessory 4 according to Figure 7.\n\n```mermaid\ngraph TD\n    A[Battery Rack Frame] --> B[Accessory 2]\n    A --> C[Accessory 4]\n    B --> D[Top of Rack]\n    C --> E[Side of Rack]\n```\n\nFigure 7  Installation procedure of accessory 2 and accessory 4\n\nChunk 5 trong file Netsure 731 A41 Usermanual.pdf tại trang 35, có chứa bảng None và hình None có nội dung:\n## 2. Installation Instruction Of Three-Layer Battery Rack\n\n'},
#  'B4706': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Yêu cầu chung',
#   'value': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#   'yeu_cau_ky_thuat_chi_tiet': 'Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file Netsure 731 A41 Usermanual.pdf tại trang 1, có chứa bảng None và hình None có nội dung:\n# System User Manual\n\n资料版本 V1.1\n\nVersion V1.1.\n\n归档日期 2017-10-22\n\nNew product Netsure 731 A41-S8 added\n\nBOM 编码 31013139\n\nRevision date October 22, 2017\n\nBOM 31013139\n\n艾默生网络能源有限公司为客户提供全方位的技术支持，用户可与就近的艾默生网络能源有限公司办事处或客户服务中心联系，也可直接与公司总部联系。\n\n艾默生网络能源有限公司\n\nCopyright © 2017 by Vertiv Co., Ltd.\n\n版权所有，保留一切权利。内容如有改动，恕不另行通知。\n\n艾默生网络能源有限公司\n\nVertiv Co., Ltd.\n\n地址：\n\n深圳市南山区学苑大道 1001 号南山智园 B2 栋\n\nAddress: Block B2, Nanshan I Park, No.1001 Xueyuan Road, Nanshan District, Shenzhen, 518055, P.R.China\n\n邮编：518055\n\n公司网址：Homepage: www.Vertiv.com\n\nwww.Vertivco.com\n\n客户服务热线：4008876510\n\nE-mail：Service@vertivco.com\n\n\n\n\n\nNO_CONTENT_HERE\n\nChunk 2 trong file Netsure 731 A41 Usermanual.pdf tại trang 30, có chứa bảng Technical and Engineering Data và hình None có nội dung:\n## Appendix 1 Technical And Engineering Data\n\n| Parameter category             | Parameter                                        | Description                                                                                                                     |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| Environmental                  | Operating temperature                            | －10℃～＋70℃(derating is necessary above 40°C)                                                                                     |\n|                                | Storage temperature                              | －40℃～＋85℃                                                                                                                       |\n|                                | Relative humidity                                | 5％RH～95％RH                                                                                                                      |\n|                                | Altitude                                         | < 3000m (derating is necessary above 3,000m)                                                                                    |\n|                                | Polution level                                   | Level 2                                                                                                                         |\n|                                | Others                                           | No conductive dust or erosive gases. No possibility of explosion                                                                |\n| AC input                       | AC input system                                  | L＋N＋PE/220Vac；3P＋N＋PE/220Vac                                                                                                    |\n|                                | AC input type                                    | TN，TT                                                                                                                           |\n|                                | Input voltage range                              | 85Vac～300Vac                                                                                                                    |\n|                                | Input AC voltage frequency                       | 45Hz～65Hz                                                                                                                       |\n|                                | Maximum input current                            | ≤74A（including 10A AC output current）forS1, S2；≤110A for S8                                                                     |\n|                                | Power factor                                     | ≥0.99                                                                                                                 ...
#  'A09AB': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#   'yeu_cau_ky_thuat_chi_tiet': 'Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': "Chunk 1 trong file Netsure 731 A41 Usermanual.pdf tại trang 27, có chứa bảng None và hình None có nội dung:\n### R48-3000e3 Replacement\n\nRectifier modules can be inserted or removed with power applied (hot swappable).\n\n> Note:\n> \n> Each rectifier module locks into a module mounting shelf by means of a latch located on the bottom of the module. The latch and rectifier module handle are interactive. Pushing the handle up into the module's front panel causes the latch to extend to the locking position; pulling the handle down out from the module's front panel causes the latch to retract.\n\n⚠️ DANGER!\n\nTake care when removing a rectifier module that was in operation, as rectifier module surfaces could be very hot.\n\n⚠️ WARNING!\n\nTo prevent damage to the latching mechanism, ensure the handle is in the open position when installing or removing a rectifier module. NEVER hold the handle in the closed position when installing a rectifier module into a shelf.\n\nChunk 2 trong file Netsure 731 A41 Usermanual.pdf tại trang 27, có chứa bảng None và hình Figure 4-5 Installing Rectifier có nội dung:\n### Procedure\n\nRefer to Figure 4-5 as this procedure is performed.\n\n1. Performing this procedure may activate external alarms. Do one of the following. If possible, disable these alarms. If these alarms cannot be easily disabled, notify the appropriate personnel to disregard any alarms associated with this system while this procedure is performed.\n\nNetSure 731 A41 Subrack Power System User Manual\n\n\n\n\n\n20    Chapter 4 Troubleshooting\n\n2. Loosen the captive screw on the module's handle. Pull the handle down out from the module's front panel (this will also retract the latch mechanism).\n\n3. Grasp the handle and pull firmly to remove the module from the shelf.\n\n4. Place the replacement rectifier module into the mounting position without sliding it in completely.\n\n5. Loosen the captive screw on the module's handle. Pull the handle down out from the module's front panel (this will also retract the latch mechanism).\n\n6. Push the module completely into the shelf.\n\n7. Push the handle up into the module's front panel. This will lock the module securely to the shelf.  Tighten the captive screw on the handle.\n\n8. Certain functions (i.e. rectifier current limit, rectifier addressing) may require adjustment when adding or replacing a rectifier module.\n\n9. After the rectifier modules are physically installed in the mounting shelf(s), they are ready for operation immediately after power is supplied to them. Verify that the rectifiers are operating normally.\n\n10. Enable the external alarms, or notify appropriate personnel that this procedure is finished.\n\n11. Ensure that there are no local or remote alarms active on the system.\n\n```mermaid\ngraph TD\n    A[Latch] --> B\n    B[Module Shelf] --> C\n    C[Module Front Panel] --> D[Screw]\n    C --> E[Handle]\n    F[Open the handle] --> G[Module Front Panel with Open Handle]\n```\n\nFigure 4-5  Installing Rectifier\n\nChunk 3 trong file netsure-801-brochure.pdf tại trang 5, có chứa bảng Rectifier Cabinet Configuration và hình None có nội dung:\n### Rectifier Cabinet Configuration\n\n| Model                        | Rack 1000-A                      | Rack 1500-A                      | Rack 2000-A                      |\n| ---------------------------- | -------------------------------- | -------------------------------- | -------------------------------- |\n| Rectifier Model              | R48-5800A/R48-5800e              | R48-5800A/R48-5800e              | R48-5800A/R48-5800e              |\n| No of Rectifier Modules      | 1-10                             | 1-15                             | 1-20                             |\n| Control Model                | M831D                            | M831D                            | M831D                            |\n| No of Control Modules        | 1                                | 1                 ...
#  '9F080': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat_chi_tiet': 'Công suất mỗi module chỉnh lưu: ≥ 3000W',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file netsure-801-brochure.pdf tại trang 4, có chứa bảng Power Supply Specifications và hình None có nội dung:\n### General\n\n| Power Supply               | 19VDC to 60VDC |\n| -------------------------- | -------------- |\n| Power consumption, Maximum | 18W            |\n\nChunk 2 trong file netsure-801-brochure.pdf tại trang 5, có chứa bảng Output Parameters Configuration và hình Relationship between the Output power & Input voltage at 45°C có nội dung:\n### Output Parameters\n\n| Output Voltage       | -42 \\~ -58Vdc                                |\n| -------------------- | -------------------------------------------- |\n| Output Current       | 0 \\~ 120.8A                                  |\n| Maximum Output Power | 5800W ( 100A @ 58Vdc)                        |\n| Power Density        | 13.5W/In³ - 85 (H) x 224 (W) x 371 (D) in mm |\n| Efficiency           | >93% (R48-5800A)<br/>>96% (R48-5800e)        |\n\n\n| ![Graph showing relationship between Output power & Input voltage at 45°C]() Relationship between the Output power & Input voltage at 45°C                                                           |\n| ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |\n| ![Graph showing relationship between Output power & Ambient temperature when Vin is larger than 304Vac]() Relationship between the Output power & Ambient temperature when Vin is larger than 304Vac |\n\nChunk 3 trong file netsure-801-brochure.pdf tại trang 5, có chứa bảng Input Parameters và hình None có nội dung:\n### Input Parameters\n\n| Input Voltage   | 260 \\~ 530Vac          | ![R48-5800e module image]() |\n| --------------- | ---------------------- | --------------------------- |\n| Input Frequency | 45 \\~ 65Hz             |                             |\n| Power Factor    | ≥ 0.99                 |                             |\n| THD             | ≤5% (50% \\~ 110% load) |                             |\n\nChunk 4 trong file Netsure 731 A41 Usermanual.pdf tại trang 30, có chứa bảng Technical and Engineering Data và hình None có nội dung:\nNetSure 731 A41 Subrack Power System User Manual\n\n\n\n\n\nAppendix 1    Technical And Engineering Data    23\n\n| Parameter category             | Parameter                               | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |                                                                                                                                                                                                                                                                                                  |\n| ------------------------------ | --------------------------------------- | ------------------------------------------------------------------------------------------------ ...
#  '5F95F': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#   'yeu_cau_ky_thuat_chi_tiet': 'Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file netsure-801-brochure.pdf tại trang 4, có chứa bảng Power Supply Specifications và hình None có nội dung:\n### General\n\n| Power Supply               | 19VDC to 60VDC |\n| -------------------------- | -------------- |\n| Power consumption, Maximum | 18W            |\n\nChunk 2 trong file netsure-801-brochure.pdf tại trang 5, có chứa bảng Rectifier Cabinet Configuration và hình None có nội dung:\n### Rectifier Cabinet Configuration\n\n| Model                        | Rack 1000-A                      | Rack 1500-A                      | Rack 2000-A                      |\n| ---------------------------- | -------------------------------- | -------------------------------- | -------------------------------- |\n| Rectifier Model              | R48-5800A/R48-5800e              | R48-5800A/R48-5800e              | R48-5800A/R48-5800e              |\n| No of Rectifier Modules      | 1-10                             | 1-15                             | 1-20                             |\n| Control Model                | M831D                            | M831D                            | M831D                            |\n| No of Control Modules        | 1                                | 1                                | 1                                |\n| Dimensions (W x D x H) in mm | 600 x 600 x 2000                 | 600 x 600 x 2000                 | 600 x 600 x 2000                 |\n| Weight (kg)                  | <140 (without rectifier modules) | <160 (without rectifier modules) | <180 (without rectifier modules) |\n\n\n[Images of three different rack configurations: Rack 1000-A, Rack 1500-A, and Rack 2000-A]\n\nChunk 3 trong file netsure-801-brochure.pdf tại trang 5, có chứa bảng Input Parameters và hình None có nội dung:\n### Input Parameters\n\n| Input Voltage   | 260 \\~ 530Vac          | ![R48-5800e module image]() |\n| --------------- | ---------------------- | --------------------------- |\n| Input Frequency | 45 \\~ 65Hz             |                             |\n| Power Factor    | ≥ 0.99                 |                             |\n| THD             | ≤5% (50% \\~ 110% load) |                             |\n\nChunk 4 trong file netsure-701-series_datasheet_en-asia.pdf tại trang 2, có chứa bảng Controller Module-M830D Specifications và hình None có nội dung:\n## Controller Module-M830D\n\n| Display                 | 320 x 240 Pixels TFT LCD                                                                                                                                              |\n| ----------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------- |\n| Communication Interface | RS 232, Rs485, Ethernet, USB                                                                                                                                          |\n| Protocol                | IPv4, IPv6, HTTPS, SNMP V2/V3, EEM, SocTpe, Rsoc, Modbus                                                                                                              |\n| Input                   | **Analog:** 3 temperatures, 2 battery currents, 1 load current, 1 bus voltage, 2 battery voltages, 1 fuel level sensor and much more with additional interface boards |\n|                         | **Digital:** 1 input for status of surge protective device auxiliary contacts, 12 load fuses, 6 battery fuses, bi-stable contactor status                             |\n| Protocol                | 3 LVD mono & bistable contactors                                                                                                                                      |\n| Key Features            | • Menu operated and user friendly<br/>• Intelligent battery management<br/>• Stores up to 4000 alarm history logs<br/>• Energy saving and Power split function        |\n\nChunk 5 trong file netsure- ...
#  'FC80B': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Cấu hình thiết bị nguồn',
#   'value': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#   'yeu_cau_ky_thuat_chi_tiet': 'Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file netsure-801-brochure.pdf tại trang 7, có chứa bảng Cabinet Configuration và hình None có nội dung:\n## Cabinet configuration\n\n|                         | PD48/1600DF-A-Y1                                                                 | PD48/1600DF-A-Y2                                                                | PD48/2500DF-A-Y1                                                                  | PD48/2500DF-A-Y2                                                                 | PD48/2500DF-A-Y3                                                                  |\n| ----------------------- | -------------------------------------------------------------------------------- | ------------------------------------------------------------------------------- | --------------------------------------------------------------------------------- | -------------------------------------------------------------------------------- | --------------------------------------------------------------------------------- |\n| Battery fuse            | 2 strings of<br/>2 x 800A (NT4)<br/><br/>12 × 400A (NT3)<br/><br/>4 × 200A (NT2) | 2 strings of<br/>2 x 800A (NT4)<br/><br/>4 × 630A (NT3)<br/><br/>6 × 500A (NT3) | 2 strings of<br/>2 x 1000A (NT4)<br/><br/>16 × 500A (NT3)<br/><br/>4 × 200A (NT2) | 2 strings of<br/>2 x 1000A (NT4)<br/><br/>6 × 630A (NT3)<br/><br/>8 × 500A (NT2) | 2 strings of<br/>2 x 1000A (NT4)<br/><br/>12 × 500A (NT3)<br/><br/>2 × 200A (NT2) |\n| DC output               | 2 × 100A (NT00)                                                                  | 4 × 200A (NT2)<br/>2 × 100A (NT00)                                              | 2 × 100A (NT00)                                                                   | 4 × 400A (NT2)<br/>2 × 100A (NT00)                                               | 4 × 100A (NT00)                                                                   |\n| Shunt Current Detection | 8 shunts                                                                         | 4 shunts                                                                        | 8 shunts                                                                          | 6 shunts                                                                         | 12 shunts                                                                         |\n\nChunk 2 trong file Netsure 731 A41 Usermanual.pdf tại trang 30, có chứa bảng Technical and Engineering Data và hình None có nội dung:\n## Appendix 1 Technical And Engineering Data\n\n| Parameter category             | Parameter                                        | Description                                                                                                                     |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| Environmental                  | Operating temperature                            | －10℃～＋70℃(derating is necessary above 40°C)                                                                                     |\n|                                | Storage temperature                              | －40℃～＋85℃                                                                                                                       |\n|                                | Relative humidity                                | 5％RH～95％RH                                                                                                                      |\n|                                | Altitude                                         | < 3000m (derating is necessary above 3,000m)                                                                                    |\n|                                | Polution level                                   | Level 2                          ...
#  '5552C': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Sử dụng được các điện áp L＋N＋PE/220VAC',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file Netsure 731 A41 Usermanual.pdf tại trang 10, có chứa bảng Table 1-1 Configuration of power system và hình None có nội dung:\n### Configuration\n\nThe configuration of the power system is listed in Table 1-1.\n\n| Item                         | NetSure 731 A41-S1              | NetSure 731 A41-S2              | NetSure 731 A41-S8                              |\n| ---------------------------- | ------------------------------- | ------------------------------- | ----------------------------------------------- |\n| Controller                   | Model: M225S                    | Model: M221S/M222S              | Model: M221S/M830B                              |\n| Rectifier                    | Model:                          | Model:                          | Model:                                          |\n|                              | R48-3000e3                      | R48-3000e3                      | R48-3000a3/ R48-3000e3/ R48-3500e3/             |\n|                              | Maximum configuration: 4 pieces | Maximum configuration: 4 pieces | Maximum configuration: 5 pieces                 |\n| AC power distribution        | L＋N＋PE/220Vac                   | L＋N＋PE/220Vac                   | L＋N＋PE/220Vac, 3P+N+PE/380Vac                   |\n| DC power distribution        | PL:                             | PL:                             | PL:                                             |\n|                              | 32A/1P×2;16A/1P×2 MCB           | 32A/1P×2;16A/1P×2 MCB           | 50A/1P×3 MCB                                    |\n|                              | NPL:                            | NPL:                            | NPL:                                            |\n|                              | 63A/1P×2;32A/1P×4;16A/1P×2 MCB  | 63A/1P×2; 32A/1P×4;16A/1P×2 MCB | 16A/1P×3 MCB Available space for additional MCB |\n| AC output MCB                | 1×16A/1P                        | 1×16A/1P                        | 1×16A/1P                                        |\n| Battery MCB                  | 2×125A/1P                       | 2×125A/1P                       | 4×125A/1P                                       |\n| AC SPD                       | 1 piece                         | 1piece                          | 1piece                                          |\n| DC SPD                       | 1piece                          | 1piece                          | 1piece                                          |\n| Cover                        | Optional                        | Optional                        | Optional                                        |\n| BLVD controller control mode | Controller power-losing mode    | Controller power-losing mode    | Controller power-losing mode                    |\n\nChunk 2 trong file netsure-801-brochure.pdf tại trang 6, có chứa bảng None và hình None có nội dung:\n# AC Distribution Cabinet\n\n- Intelligent & compact design; independent operation\n\n- Equipped with an advanced monitoring unit that displays the input AC voltage, current, frequency & SPD status parameters\n\n- Audible and visual alarm reporting for local input over voltage and under voltage, frequency anomalies, and SPD faults\n\n- Manual and Automatic switching of the two mains input in a secure & reliable way.\n\n- Emergency DC lighting for easy maintenance\n\n- Built-in top & bottom cabling with frontal access for ultimate convenience and flexibility.\n\n- Safety regulations and SPD systems meet the industry-level IEC standards while guaranteeing device-and-body safety.\n\n- Meets the stringent environmental protection requirements of the European Union and China.\n\nChunk 3 trong file Netsure 731 A41 Usermanual.pdf tại trang 10, có chứa bảng None và hình None có nội dung:\n### Main Features\n\n- The rectifier uses the active Power Factor Compensation(PFC) technology and the power factor is up to 0.99.\n- The power system has wide AC in ...
#  '3513E': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu vào AC',
#   'value': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#   'yeu_cau_ky_thuat_chi_tiet': 'Dải điện áp đầu vào từ 85VAC ÷ 300VAC',
#   'yeu_cau_ky_thuat': None,
# ...
#  '97B78': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Độ ổn định điện áp đầu ra: ≤1%',
#   'yeu_cau_ky_thuat_chi_tiet': 'Độ ổn định điện áp đầu ra: ≤1%',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file Netsure 731 A41 Usermanual.pdf tại trang 30, có chứa bảng Technical and Engineering Data và hình None có nội dung:\n## Appendix 1 Technical And Engineering Data\n\n| Parameter category             | Parameter                                        | Description                                                                                                                     |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| Environmental                  | Operating temperature                            | －10℃～＋70℃(derating is necessary above 40°C)                                                                                     |\n|                                | Storage temperature                              | －40℃～＋85℃                                                                                                                       |\n|                                | Relative humidity                                | 5％RH～95％RH                                                                                                                      |\n|                                | Altitude                                         | < 3000m (derating is necessary above 3,000m)                                                                                    |\n|                                | Polution level                                   | Level 2                                                                                                                         |\n|                                | Others                                           | No conductive dust or erosive gases. No possibility of explosion                                                                |\n| AC input                       | AC input system                                  | L＋N＋PE/220Vac；3P＋N＋PE/220Vac                                                                                                    |\n|                                | AC input type                                    | TN，TT                                                                                                                           |\n|                                | Input voltage range                              | 85Vac～300Vac                                                                                                                    |\n|                                | Input AC voltage frequency                       | 45Hz～65Hz                                                                                                                       |\n|                                | Maximum input current                            | ≤74A（including 10A AC output current）forS1, S2；≤110A for S8                                                                     |\n|                                | Power factor                                     | ≥0.99                                                                                                                           |\n|                                | Overvoltage level                                | Level Ⅱ                                                                                                                         |\n|                                | Nominal output voltage                           | －48Vdc                                                                                                                          |\n|                                | Rated output voltage                             | －53.5Vdc（If it is used for outdoor，the rated voltage is-54V）                                                                    |\n| DC output                      | Output DC voltage                                | －42 ～－58Vdc         ...
#  '070AF': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#   'yeu_cau_ky_thuat_chi_tiet': 'Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file netsure-801-brochure.pdf tại trang 5, có chứa bảng Input Parameters và hình None có nội dung:\n### Input Parameters\n\n| Input Voltage   | 260 \\~ 530Vac          | ![R48-5800e module image]() |\n| --------------- | ---------------------- | --------------------------- |\n| Input Frequency | 45 \\~ 65Hz             |                             |\n| Power Factor    | ≥ 0.99                 |                             |\n| THD             | ≤5% (50% \\~ 110% load) |                             |\n\nChunk 2 trong file Netsure 731 A41 Usermanual.pdf tại trang 30, có chứa bảng Technical and Engineering Data và hình None có nội dung:\n## Appendix 1 Technical And Engineering Data\n\n| Parameter category             | Parameter                                        | Description                                                                                                                     |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| Environmental                  | Operating temperature                            | －10℃～＋70℃(derating is necessary above 40°C)                                                                                     |\n|                                | Storage temperature                              | －40℃～＋85℃                                                                                                                       |\n|                                | Relative humidity                                | 5％RH～95％RH                                                                                                                      |\n|                                | Altitude                                         | < 3000m (derating is necessary above 3,000m)                                                                                    |\n|                                | Polution level                                   | Level 2                                                                                                                         |\n|                                | Others                                           | No conductive dust or erosive gases. No possibility of explosion                                                                |\n| AC input                       | AC input system                                  | L＋N＋PE/220Vac；3P＋N＋PE/220Vac                                                                                                    |\n|                                | AC input type                                    | TN，TT                                                                                                                           |\n|                                | Input voltage range                              | 85Vac～300Vac                                                                                                                    |\n|                                | Input AC voltage frequency                       | 45Hz～65Hz                                                                                                                       |\n|                                | Maximum input current                            | ≤74A（including 10A AC output current）forS1, S2；≤110A for S8                                                                     |\n|                                | Power factor                                     | ≥0.99                                                                                                                           |\n|                                | Overvoltage level                                | Level Ⅱ                                                                                                                         |\n|                ...
#  '1F101': {'ten_san_pham': 'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)',
#   'ten_hang_hoa': 'Đầu ra DC',
#   'value': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#   'yeu_cau_ky_thuat_chi_tiet': 'Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)',
#   'yeu_cau_ky_thuat': None,
#   'relevant_context': 'Chunk 1 trong file Netsure 731 A41 Usermanual.pdf tại trang 30, có chứa bảng Technical and Engineering Data và hình None có nội dung:\n## Appendix 1 Technical And Engineering Data\n\n| Parameter category             | Parameter                                        | Description                                                                                                                     |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| Environmental                  | Operating temperature                            | －10℃～＋70℃(derating is necessary above 40°C)                                                                                     |\n|                                | Storage temperature                              | －40℃～＋85℃                                                                                                                       |\n|                                | Relative humidity                                | 5％RH～95％RH                                                                                                                      |\n|                                | Altitude                                         | < 3000m (derating is necessary above 3,000m)                                                                                    |\n|                                | Polution level                                   | Level 2                                                                                                                         |\n|                                | Others                                           | No conductive dust or erosive gases. No possibility of explosion                                                                |\n| AC input                       | AC input system                                  | L＋N＋PE/220Vac；3P＋N＋PE/220Vac                                                                                                    |\n|                                | AC input type                                    | TN，TT                                                                                                                           |\n|                                | Input voltage range                              | 85Vac～300Vac                                                                                                                    |\n|                                | Input AC voltage frequency                       | 45Hz～65Hz                                                                                                                       |\n|                                | Maximum input current                            | ≤74A（including 10A AC output current）forS1, S2；≤110A for S8                                                                     |\n|                                | Power factor                                     | ≥0.99                                                                                                                           |\n|                                | Overvoltage level                                | Level Ⅱ                                                                                                                         |\n|                                | Nominal output voltage                           | －48Vdc                                                                                                                          |\n|                                | Rated output voltage                             | －53.5Vdc（If it is used for outdoor，the rated voltage is-54V）                                                                    |\n| DC output                      | Output DC voltage                                | －42 ～－58Vdc         ...

# %%
SYSTEM_PROMPT = """
Bạn được cung cấp:
- Một hoặc nhiều đoạn văn bản (chunk) từ tài liệu kỹ thuật, kèm metadata: tên file, mục, bảng/hình (nếu có), số trang
- Một yêu cầu kỹ thuật cụ thể.
- Một đoạn văn mẫu.

#Yêu cầu trả lời bằng tiếng việt:
# 1. Tìm thông tin kỹ thuật liên quan trực tiếp đến yêu cầu kỹ thuật.
# 2. Trích xuất giá trị thông số để xác định khả năng đáp ứng theo yêu cầu và trả về đoạn văn tương tự giống đoạn văn mẫu không thêm bớt nhưng thông số phải chính xác trong tài liệu.
# 3. Dẫn chứng rõ: file, section, table/figure name (nếu có), page, nội dung trích dẫn của những tài liệu liên quan, những tài liệu khác không liên quan thì bỏ qua.

# #Output: JSON gồm các trường:
- yeu_cau_ky_thuat
- kha_nang_dap_ung
- tai_lieu_tham_chieu" 

# Ví dụ:
Input:
Yêu cầu: "Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4"  
Chunk: "...NetSure 731 A41-S8: 4 rectifier slots (standard), expandable to 6..."  
Metadata:  
- file: "Netsure-731-A41-user-manual.pdf"  
- section: "Table 1-1 Configuration of power system"  
- page: 2"
Đoạn văn mẫu: Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4 (ví dụ tìm trong tài liệu số lượng là 5 thì trả về "Số lượng khe cắm module chỉnh lưu (Rectifier): 5")
"""

# Định nghĩa function schema
FUNCTION_SCHEMA = {
    "name": "danh_gia_ky_thuat",
    "description": "Đánh giá khả năng đáp ứng của sản phẩm theo yêu cầu kỹ thuật từ chunk tài liệu.",
    "parameters": {
        "type": "object",
        "properties": {
            "yeu_cau_ky_thuat": {"type": "string"},
            "kha_nang_dap_ung": {"type": "string"},
            "tai_lieu_tham_chieu": {
                "type": "object",
                "properties": {
                    "file": {"type": "string"},
                    "section": {"type": "string"},
                    "table_or_figure": {"type": "string"},
                    "page": {"type": "integer"},
                    "evidence": {"type": "string"}
                },
                "required": ["file", "section", "page", "evidence"]
            }
        },
        "required": ["yeu_cau_ky_thuat", "kha_nang_dap_ung", "tai_lieu_tham_chieu"]
    }
}

# %%
# Tạo assistant
# === CREATE ASSISTANT ===
def create_assistant():
    assistant = client.beta.assistants.create(
        name="Technical Document Evaluator",
        instructions=SYSTEM_PROMPT,
        model="gpt-4o-mini",
        tools=[{"type": "function", "function": FUNCTION_SCHEMA}]
    )
    return assistant.id

# === CREATE THREAD ===
def create_thread():
    thread = client.beta.threads.create()
    return thread.id

# === UPDATE ASSISTANT ===
def update_assistant(assistant_id):
    assistant = client.beta.assistants.update(
        assistant_id=assistant_id,
        instructions=SYSTEM_PROMPT,
        model="gpt-4o-mini",
        tools=[{"type": "function", "function": FUNCTION_SCHEMA}]
    )
    return assistant.id

# === EVALUATE TECHNICAL REQUIREMENT ===
def evaluate_technical_requirement(user_prompt, assistant_id):
    # 1. Tạo thread riêng cho mỗi lần gọi
    thread = client.beta.threads.create()
    thread_id = thread.id

    # 2. Gửi message vào thread
    client.beta.threads.messages.create(
        thread_id=thread_id,
        role="user",
        content=user_prompt
    )

    # 3. Tạo run
    run = client.beta.threads.runs.create(
        thread_id=thread_id,
        assistant_id=assistant_id,
        tool_choice={"type": "function", "function": {"name": "danh_gia_ky_thuat"}}
    )

    # 4. Chờ assistant xử lý (tối đa 20s)
    for _ in range(20):
        run = client.beta.threads.runs.retrieve(thread_id=thread_id, run_id=run.id)
        if run.status not in ["queued", "in_progress"]:
            break
        time.sleep(1)

    # 5. Lấy arguments trực tiếp
    if run.status == "requires_action":
        call = run.required_action.submit_tool_outputs.tool_calls[0]
        print(f"👉 Assistant đã gọi tool: {call.function.name}")
        print("🧠 Dữ liệu JSON assistant muốn trả về:")
        print(call.function.arguments)
        return call.function.arguments

    elif run.status == "completed":
        messages = client.beta.threads.messages.list(thread_id=thread_id)
        for msg in messages.data:
            print(f"[{msg.role}] {msg.content[0].text.value}")
        return None

    else:
        print(f"Run status: {run.status}")
        return None

# %%
test

# %%
import openai
from openai import OpenAI
import json
client = OpenAI()

# %%
# Ví dụ sử dụng
import time
assistant_id = create_assistant()
print(f"Assistant ID: {assistant_id}")


# Ví dụ user prompt

for key in test:
    if not test[key].get('relevant_context'):
        continue
    data = test[key]
    value = data['value']
    content = data['relevant_context']
    form = data['yeu_cau_ky_thuat_chi_tiet']
    # test[key].pop("content", None)
    
    user_prompt = f'''
    Chunk và metadata: {content}
    Yêu cầu: {value}
    Đoạn văn mẫu: {form}
    '''
    
    # Gọi hàm đánh giá với thread riêng
    result = evaluate_technical_requirement(user_prompt, assistant_id)
    test[key]['response'] = result
# Out:
# Assistant ID: asst_GSwnCj1QUblmj0gJXvLOmqU6
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16896\985798817.py:30: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   thread = client.beta.threads.create()
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16896\985798817.py:34: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   client.beta.threads.messages.create(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16896\985798817.py:41: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   run = client.beta.threads.runs.create(
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16896\985798817.py:49: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   run = client.beta.threads.runs.retrieve(thread_id=thread_id, run_id=run.id)
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Thiết bị mới 100% chưa qua sử dụng","kha_nang_dap_ung":"Thiết bị mới 100% chưa qua sử dụng","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Unpacking inspection","page":11,"evidence":"The equipment should be unpacked and inspected after it arrives at the installation site. The inspection shall be done by representatives of both the user and Vertiv Co., Ltd. To inspect the equipment, you should open the packing case, take out the packing list and check against the packing list that the equipment is correct and complete. Make sure that the equipment is delivered intact."}}]}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Thiết bị phải được sản xuất từ năm 2021 trở lại đây","kha_nang_dap_ung":"Không đáp ứng được yêu cầu","tai_lieu_tham_chieu":{"file":"netsure-2100-brochure.pdf","section":"Technical Specifications of NETSURE™ 2100 A31-S2 and A31-S3","page":2,"evidence":"Specifications are subject to change without notice. November 2018"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Tuân thủ tiêu chuẩn IEC 60950-1","kha_nang_dap_ung":"Tuân thủ tiêu chuẩn IEC 60950-1","tai_lieu_tham_chieu":{"file":"Netsure-801-brochure.pdf","section":"Safety & standard compliance","page":4,"evidence":"| Electrical    | IEC 60950-1, EN 60950-1, UL 60950-1            |"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.","kha_nang_dap_ung":"Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Composition","table_or_figure":"None","page":9,"evidence":"The power system is composed of power distribution、rectifier modules and controller module."}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Tất cả các khối đặt trong tủ liên hoàn, đồng bộ của hãng, tạo thành thiết bị cấp nguồn và nạp acquy hoàn chỉnh.","kha_nang_dap_ung":"Đã có tất cả các phụ kiện cần thiết cho việc lắp đặt và đảm bảo hệ thống hoạt động đồng bộ và hoàn chỉnh.","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Packing List of Accessories","table_or_figure":"Figure 5 Accessory showing four components of the battery rack","page":35,"evidence":"Để lắp đặt hoàn chỉnh cho bộ cấp nguồn và nạp acquy, các phụ kiện sau đây được sử dụng: Accessory 1 (main frame), Accessory 2 (support bar), Accessory 3 (long bar), Accessory 4 (small bracket), Expansion bolt, và Fastener."}}]}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.","kha_nang_dap_ung":"Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.","tai_lieu_tham_chieu":{"file":"Netsure-731-A41-user-manual.pdf","section":"System User Manual","page":1,"evidence":"NO_CONTENT_HERE"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4","kha_nang_dap_ung":"Số lượng khe cắm module chỉnh lưu (Rectifier): 4 x R48-3000A3 / R48-3000e3 / R48-3500e3 / R48-3500OE4","tai_lieu_tham_chieu":{"file":"NetSure -731 A41 Brochure.pdf","section":"NetSure™ 731 A41 Configuration","table_or_figure":"None","page":1,"evidence":"| Rectifier            | 4 x R48-3000A3 / R48-3000e3 / R48-3500e3 / R48-3500OE4 |"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Công suất mỗi module chỉnh lưu: ≥ 3000W","kha_nang_dap_ung":"Công suất mỗi module chỉnh lưu: 3000W (mặc định)","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1    Technical And Engineering Data","page":30,"evidence":"Default: dưới 45℃, 3000W 출력."}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module","kha_nang_dap_ung":"Số lượng module chỉnh lưu trang bị kèm tủ nguồn: 1-20 module","tai_lieu_tham_chieu":{"file":"netsure-801-brochure.pdf","section":"Rectifier Cabinet Configuration","table_or_figure":"Bảng","page":5,"evidence":"Số lượng module chỉnh lưu: 1-20"}}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái","kha_nang_dap_ung":"Attomat DC: + PL (Priority LLVD) ● Loại 32A: 2 cái ● Loại 16A: 1 cái + NPL (Non Priority LLVD): ● Loại 63A: 2 cái ● Loại 32A: 2 cái ● Loại 16A: 2 cái + Attomat cho acquy: ●  Loại 125A: 2 cái","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Table 1-1 Configuration of power system","page":10,"evidence":"| Battery MCB                  | 2×125A/1P                       | 2×125A/1P                       | 4×125A/1P                                       |"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Sử dụng được các điện áp L＋N＋PE/220VAC","kha_nang_dap_ung":"Sử dụng được các điện áp L＋N＋PE/220Vac","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","page":30,"evidence":"AC input system L＋N＋PE/220Vac；3P＋N＋PE/220Vac"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Dải điện áp đầu vào từ 85VAC ÷ 300VAC","kha_nang_dap_ung":"Dải điện áp đầu vào từ 85VAC ÷ 300VAC","tai_lieu_tham_chieu":{"file":"Netsure-731-A41-user-manual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"None","page":30,"evidence":"| AC input | Input voltage range | 85Vac～300Vac |"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.","kha_nang_dap_ung":"Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"Technical and Engineering Data","page":30,"evidence":"Dải tần số AC đầu vào từ 45Hz đến 65Hz."}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Có tính năng chống sét","kha_nang_dap_ung":"Có tính năng chống sét","tai_lieu_tham_chieu":{"file":"netsure-212-c23-datasheet2.pdf","section":"Key Features","page":1,"evidence":"Fully protected from external lightning surges"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Điện áp đầu ra danh định -48VDC, cực dương đấu đất","kha_nang_dap_ung":"Điện áp đầu ra danh định -48VDC, cực dương đấu đất","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"Technical and Engineering Data","page":30,"evidence":"| Nominal output voltage   | －48Vdc |"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC","kha_nang_dap_ung":"Dải điện áp đầu ra: từ -42VDC tới -58VDC","tai_lieu_tham_chieu":{"file":"netsure-701-series_datasheet_en-asia.pdf","section":"Output Data","table_or_figure":"Output Data","page":1,"evidence":"| Operating Voltage Range  | -42 Vdc to -58Vdc |"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Độ ổn định điện áp đầu ra: ≤1%","kha_nang_dap_ung":"Độ ổn định điện áp đầu ra: ≤1%","tai_lieu_tham_chieu":{"file":"Netsure-731-A41-user-manual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"None","page":30,"evidence":"| Parameter category | Parameter | Description |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| DC output | Voltage set-point accuracy | ≤1％ |"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)","kha_nang_dap_ung":"Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz - 1MHz)","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"None","page":30,"evidence":"Nhiễu băng rộng (Wide band noise) ≤20mV rms (5Hz - 1MHz)"}}
# 👉 Assistant đã gọi tool: danh_gia_ky_thuat
# 🧠 Dữ liệu JSON assistant muốn trả về:
# {"yeu_cau_ky_thuat":"Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)","kha_nang_dap_ung":"Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":null,"page":30,"evidence":"Output noise Wide band noise ≤20mV rms (5Hz - 1MHz)<br/>Peak-Peak noise ≤250mV p-p (0 - 20MHz)"}}

# %%
test

# %%
import json

for key in test:
    test[key].pop("content", None)
    response = test[key].get('response')  # Sử dụng get để tránh lỗi nếu không có response
    print(response)
    if response:
        if isinstance(response, str):
            first_json_str = response[:response.find('}}') + 2]
            response = json.loads(first_json_str)
        test[key]["kha_nang_dap_ung"] = response.get('kha_nang_dap_ung', '')
        tai_lieu_tham_chieu = {
            "file": response['tai_lieu_tham_chieu'].get('file', ''),
            "section": response['tai_lieu_tham_chieu'].get('section', ''),
            "table_or_figure": response['tai_lieu_tham_chieu'].get('table_or_figure', ''),
            "page": response['tai_lieu_tham_chieu'].get('page', 0),
            "evidence": response['tai_lieu_tham_chieu'].get('evidence', '')
        }
        test[key]["tai_lieu_tham_chieu"] = tai_lieu_tham_chieu
    test[key].pop("response", None)
# Out:
# {"yeu_cau_ky_thuat":"Thiết bị mới 100% chưa qua sử dụng","kha_nang_dap_ung":"Thiết bị mới 100% chưa qua sử dụng","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Unpacking inspection","page":11,"evidence":"The equipment should be unpacked and inspected after it arrives at the installation site. The inspection shall be done by representatives of both the user and Vertiv Co., Ltd. To inspect the equipment, you should open the packing case, take out the packing list and check against the packing list that the equipment is correct and complete. Make sure that the equipment is delivered intact."}}]}
# {"yeu_cau_ky_thuat":"Thiết bị phải được sản xuất từ năm 2021 trở lại đây","kha_nang_dap_ung":"Không đáp ứng được yêu cầu","tai_lieu_tham_chieu":{"file":"netsure-2100-brochure.pdf","section":"Technical Specifications of NETSURE™ 2100 A31-S2 and A31-S3","page":2,"evidence":"Specifications are subject to change without notice. November 2018"}}
# {"yeu_cau_ky_thuat":"Tuân thủ tiêu chuẩn IEC 60950-1","kha_nang_dap_ung":"Tuân thủ tiêu chuẩn IEC 60950-1","tai_lieu_tham_chieu":{"file":"Netsure-801-brochure.pdf","section":"Safety & standard compliance","page":4,"evidence":"| Electrical    | IEC 60950-1, EN 60950-1, UL 60950-1            |"}}
# {"yeu_cau_ky_thuat":"Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.","kha_nang_dap_ung":"Thuộc loại thiết bị nguồn sử dụng kỹ thuật chuyển mạch, thiết kế dạng Module theo chức năng của từng khối.","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Composition","table_or_figure":"None","page":9,"evidence":"The power system is composed of power distribution、rectifier modules and controller module."}}
# {"yeu_cau_ky_thuat":"Tất cả các khối đặt trong tủ liên hoàn, đồng bộ của hãng, tạo thành thiết bị cấp nguồn và nạp acquy hoàn chỉnh.","kha_nang_dap_ung":"Đã có tất cả các phụ kiện cần thiết cho việc lắp đặt và đảm bảo hệ thống hoạt động đồng bộ và hoàn chỉnh.","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Packing List of Accessories","table_or_figure":"Figure 5 Accessory showing four components of the battery rack","page":35,"evidence":"Để lắp đặt hoàn chỉnh cho bộ cấp nguồn và nạp acquy, các phụ kiện sau đây được sử dụng: Accessory 1 (main frame), Accessory 2 (support bar), Accessory 3 (long bar), Accessory 4 (small bracket), Expansion bolt, và Fastener."}}]}
# {"yeu_cau_ky_thuat":"Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.","kha_nang_dap_ung":"Thời gian bảo hành: theo tiêu chuẩn của nhà sản xuất, tối thiểu 12 tháng.","tai_lieu_tham_chieu":{"file":"Netsure-731-A41-user-manual.pdf","section":"System User Manual","page":1,"evidence":"NO_CONTENT_HERE"}}
# {"yeu_cau_ky_thuat":"Số lượng khe cắm module chỉnh lưu (Rectifier): ≥ 4","kha_nang_dap_ung":"Số lượng khe cắm module chỉnh lưu (Rectifier): 4 x R48-3000A3 / R48-3000e3 / R48-3500e3 / R48-3500OE4","tai_lieu_tham_chieu":{"file":"NetSure -731 A41 Brochure.pdf","section":"NetSure™ 731 A41 Configuration","table_or_figure":"None","page":1,"evidence":"| Rectifier            | 4 x R48-3000A3 / R48-3000e3 / R48-3500e3 / R48-3500OE4 |"}}
# {"yeu_cau_ky_thuat":"Công suất mỗi module chỉnh lưu: ≥ 3000W","kha_nang_dap_ung":"Công suất mỗi module chỉnh lưu: 3000W (mặc định)","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1    Technical And Engineering Data","page":30,"evidence":"Default: dưới 45℃, 3000W 출력."}}
# {"yeu_cau_ky_thuat":"Số lượng module chỉnh lưu trang bị kèm tủ nguồn: ≥ 3 module","kha_nang_dap_ung":"Số lượng module chỉnh lưu trang bị kèm tủ nguồn: 1-20 module","tai_lieu_tham_chieu":{"file":"netsure-801-brochure.pdf","section":"Rectifier Cabinet Configuration","table_or_figure":"Bảng","page":5,"evidence":"Số lượng module chỉnh lưu: 1-20"}}}
# {"yeu_cau_ky_thuat":"Attomat DC: + PL (Priority LLVD) ● Loại 32A: ≥ 02 cái ● Loại 16A: ≥ 01 cái + NPL (Non Priority LLVD): ● Loại 63A: ≥ 02 cái ● Loại 32A: ≥ 03 cái ● Loại 16A: ≥ 02 cái + Attomat cho acquy: ●  Loại 125A: ≥ 02 cái","kha_nang_dap_ung":"Attomat DC: + PL (Priority LLVD) ● Loại 32A: 2 cái ● Loại 16A: 1 cái + NPL (Non Priority LLVD): ● Loại 63A: 2 cái ● Loại 32A: 2 cái ● Loại 16A: 2 cái + Attomat cho acquy: ●  Loại 125A: 2 cái","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Table 1-1 Configuration of power system","page":10,"evidence":"| Battery MCB                  | 2×125A/1P                       | 2×125A/1P                       | 4×125A/1P                                       |"}}
# {"yeu_cau_ky_thuat":"Sử dụng được các điện áp L＋N＋PE/220VAC","kha_nang_dap_ung":"Sử dụng được các điện áp L＋N＋PE/220Vac","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","page":30,"evidence":"AC input system L＋N＋PE/220Vac；3P＋N＋PE/220Vac"}}
# {"yeu_cau_ky_thuat":"Dải điện áp đầu vào từ 85VAC ÷ 300VAC","kha_nang_dap_ung":"Dải điện áp đầu vào từ 85VAC ÷ 300VAC","tai_lieu_tham_chieu":{"file":"Netsure-731-A41-user-manual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"None","page":30,"evidence":"| AC input | Input voltage range | 85Vac～300Vac |"}}
# {"yeu_cau_ky_thuat":"Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.","kha_nang_dap_ung":"Dải tần số AC đầu vào: từ 45 Hz ÷65 Hz.","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"Technical and Engineering Data","page":30,"evidence":"Dải tần số AC đầu vào từ 45Hz đến 65Hz."}}
# {"yeu_cau_ky_thuat":"Có tính năng chống sét","kha_nang_dap_ung":"Có tính năng chống sét","tai_lieu_tham_chieu":{"file":"netsure-212-c23-datasheet2.pdf","section":"Key Features","page":1,"evidence":"Fully protected from external lightning surges"}}
# {"yeu_cau_ky_thuat":"Điện áp đầu ra danh định -48VDC, cực dương đấu đất","kha_nang_dap_ung":"Điện áp đầu ra danh định -48VDC, cực dương đấu đất","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"Technical and Engineering Data","page":30,"evidence":"| Nominal output voltage   | －48Vdc |"}}
# {"yeu_cau_ky_thuat":"Dải điện áp đầu ra: từ -43.2VDC tới -57.6VDC","kha_nang_dap_ung":"Dải điện áp đầu ra: từ -42VDC tới -58VDC","tai_lieu_tham_chieu":{"file":"netsure-701-series_datasheet_en-asia.pdf","section":"Output Data","table_or_figure":"Output Data","page":1,"evidence":"| Operating Voltage Range  | -42 Vdc to -58Vdc |"}}
# {"yeu_cau_ky_thuat":"Độ ổn định điện áp đầu ra: ≤1%","kha_nang_dap_ung":"Độ ổn định điện áp đầu ra: ≤1%","tai_lieu_tham_chieu":{"file":"Netsure-731-A41-user-manual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"None","page":30,"evidence":"| Parameter category | Parameter | Description |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| DC output | Voltage set-point accuracy | ≤1％ |"}}
# {"yeu_cau_ky_thuat":"Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz÷1MHz)","kha_nang_dap_ung":"Nhiễu băng rộng (Wide band noise): ≤20mV rms (5Hz - 1MHz)","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":"None","page":30,"evidence":"Nhiễu băng rộng (Wide band noise) ≤20mV rms (5Hz - 1MHz)"}}
# {"yeu_cau_ky_thuat":"Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)","kha_nang_dap_ung":"Độ gợn sóng đầu ra (đỉnh – đỉnh):≤ 250 mV (0÷20MHz)","tai_lieu_tham_chieu":{"file":"Netsure 731 A41 Usermanual.pdf","section":"Appendix 1 Technical And Engineering Data","table_or_figure":null,"page":30,"evidence":"Output noise Wide band noise ≤20mV rms (5Hz - 1MHz)<br/>Peak-Peak noise ≤250mV p-p (0 - 20MHz)"}}

# %%
def prompt_adapt_or_not(dap_ung_ky_thuat: str) -> str:
    prompt = f"""
Bạn sẽ được cung cấp một danh sách các cặp “yêu cầu kỹ thuật || khả năng đáp ứng” trong file dap_ung_ky_thuat.
Nhiệm vụ của bạn:
1. Với từng cặp, đánh giá xem khả năng đáp ứng có thực sự đáp ứng yêu cầu kỹ thuật không.
2. Tổng hợp kết quả:
  – Nếu tất cả các yêu cầu đều được đáp ứng, trả về "Đáp ứng"
  – Nếu không có yêu cầu nào được đáp ứng, trả về "Không đáp ứng"
  – Nếu chỉ một phần yêu cầu được đáp ứng, trả về theo định dạng "Đáp ứng: x/y = z%", trong đó:
       - x là số yêu cầu được đáp ứng
       - y là tổng số yêu cầu
       - z% là phần trăm làm tròn đến số nguyên gần nhất
📤 Kết quả chỉ trả về dưới dạng JSON với cấu trúc sau: {{
 "đáp ứng kỹ thuật": "<kết quả đánh giá>"
}}

Danh sách các cặp “yêu cầu kỹ thuật || khả năng đáp ứng” : {dap_ung_ky_thuat}
"""
    return prompt

# %%
from openai import OpenAI
from dotenv import load_dotenv
import re
import os
load_dotenv()

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
def parse_output_text(output_text: str) -> dict:
    # B1: Loại bỏ phần ```json ... ```
    cleaned = re.sub(r"^```json\n|```$", "", output_text.strip())
    print(cleaned)
    # B2: Giải mã các ký tự escape như \n, \"
    unescaped = cleaned.encode("utf-8")

    # B3: Chuyển thành dict
    return json.loads(unescaped)

# %%
results = []
for product in product_key:
    items = product_key[product]
    for key in items:
        dap_ung_ky_thuat = ""
        tai_lieu_tham_chieu = ""
        for item in items[key]:
            if item not in test:
                continue
            yeu_cau_ky_thuat = test[item].get('yeu_cau_ky_thuat_chi_tiet', "")
            kha_nang_dap_ung = test[item].get('kha_nang_dap_ung', '')
            dap_ung_ky_thuat += f"{yeu_cau_ky_thuat} || {kha_nang_dap_ung}\n"
            
            tai_lieu = test[item].get('tai_lieu_tham_chieu', {})
            file = tai_lieu.get("file", "")
            page = tai_lieu.get("page", "")
            table_or_figure = tai_lieu.get("table_or_figure", "")
            evidence = tai_lieu.get("evidence", "")
            
            # Tạo câu mô tả tài liệu
            tai_lieu_text = f"{file}, trang: {page}"
            if table_or_figure:
                tai_lieu_text += f", trong bảng(figure): {table_or_figure}"
            tai_lieu_text += f", evidence: {evidence}\n\n"
            tai_lieu_tham_chieu += tai_lieu_text  # 🔧 thiếu dòng này

        if dap_ung_ky_thuat and tai_lieu_tham_chieu:  # Có thể dùng trực tiếp như bool
            prompt = prompt_adapt_or_not(dap_ung_ky_thuat)
            response = client.responses.create(
                model="gpt-4o-mini",
                input=prompt,
                temperature=0
            )
            output_text = response.output_text.strip()
            output_text = parse_output_text(output_text)
            print(output_text)
            product_key[product][key].append(output_text['đáp ứng kỹ thuật'])
            product_key[product][key].append(tai_lieu_tham_chieu)
# Out:
# {
#   "đáp ứng kỹ thuật": "Đáp ứng: 4/6 = 67%"
# }
#
# {'đáp ứng kỹ thuật': 'Đáp ứng: 4/6 = 67%'}
# {
#   "đáp ứng kỹ thuật": "Đáp ứng: 5/5 = 100%"
# }
#
# {'đáp ứng kỹ thuật': 'Đáp ứng: 5/5 = 100%'}
# {
#   "đáp ứng kỹ thuật": "Đáp ứng"
# }
#
# {'đáp ứng kỹ thuật': 'Đáp ứng'}
# {
#   "đáp ứng kỹ thuật": "Đáp ứng: 5/5 = 100%"
# }
#
# {'đáp ứng kỹ thuật': 'Đáp ứng: 5/5 = 100%'}

# %%
product_key
# Out:
# {'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)': {'Yêu cầu chung': ['BCCA8',
#    '93C6C',
#    '8E2C6',
#    '17415',
#    'D70B1',
#    'ABE44',
#    'B4706',
#    'Đáp ứng: 4/6 = 67%',
#    'Netsure 731 A41 Usermanual.pdf, trang: 11, evidence: The equipment should be unpacked and inspected after it arrives at the installation site. The inspection shall be done by representatives of both the user and Vertiv Co., Ltd. To inspect the equipment, you should open the packing case, take out the packing list and check against the packing list that the equipment is correct and complete. Make sure that the equipment is delivered intact.\n\nnetsure-2100-brochure.pdf, trang: 2, evidence: Specifications are subject to change without notice. November 2018\n\nNetsure-801-brochure.pdf, trang: 4, evidence: | Electrical    | IEC 60950-1, EN 60950-1, UL 60950-1            |\n\nNetsure 731 A41 Usermanual.pdf, trang: 9, trong bảng(figure): None, evidence: The power system is composed of power distribution、rectifier modules and controller module.\n\nNetsure 731 A41 Usermanual.pdf, trang: 35, trong bảng(figure): Figure 5 Accessory showing four components of the battery rack, evidence: Để lắp đặt hoàn chỉnh cho bộ cấp nguồn và nạp acquy, các phụ kiện sau đây được sử dụng: Accessory 1 (main frame), Accessory 2 (support bar), Accessory 3 (long bar), Accessory 4 (small bracket), Expansion bolt, và Fastener.\n\nNetsure-731-A41-user-manual.pdf, trang: 1, evidence: NO_CONTENT_HERE\n\n'],
#   'Cấu hình thiết bị nguồn': ['A09AB',
#    '9F080',
#    '5F95F',
#    'FC80B',
#    'Đáp ứng: 5/5 = 100%',
#    'NetSure -731 A41 Brochure.pdf, trang: 1, trong bảng(figure): None, evidence: | Rectifier            | 4 x R48-3000A3 / R48-3000e3 / R48-3500e3 / R48-3500OE4 |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, evidence: Default: dưới 45℃, 3000W 출력.\n\nnetsure-801-brochure.pdf, trang: 5, trong bảng(figure): Bảng, evidence: Số lượng module chỉnh lưu: 1-20\n\nNetsure 731 A41 Usermanual.pdf, trang: 10, evidence: | Battery MCB                  | 2×125A/1P                       | 2×125A/1P                       | 4×125A/1P                                       |\n\n'],
#   'Đầu vào AC': ['5552C',
#    '3513E',
#    '0C362',
#    '80D4F',
#    'Đáp ứng',
#    'Netsure 731 A41 Usermanual.pdf, trang: 30, evidence: AC input system L＋N＋PE/220Vac；3P＋N＋PE/220Vac\n\nNetsure-731-A41-user-manual.pdf, trang: 30, trong bảng(figure): None, evidence: | AC input | Input voltage range | 85Vac～300Vac |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): Technical and Engineering Data, evidence: Dải tần số AC đầu vào từ 45Hz đến 65Hz.\n\nnetsure-212-c23-datasheet2.pdf, trang: 1, evidence: Fully protected from external lightning surges\n\n'],
#   'Đầu ra DC': ['6D7D8',
#    '3323F',
#    '97B78',
#    '070AF',
#    '1F101',
#    'Đáp ứng: 5/5 = 100%',
#    'Netsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): Technical and Engineering Data, evidence: | Nominal output voltage   | －48Vdc |\n\nnetsure-701-series_datasheet_en-asia.pdf, trang: 1, trong bảng(figure): Output Data, evidence: | Operating Voltage Range  | -42 Vdc to -58Vdc |\n\nNetsure-731-A41-user-manual.pdf, trang: 30, trong bảng(figure): None, evidence: | Parameter category | Parameter | Description |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| DC output | Voltage set-point accuracy | ≤1％ |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): None, evidence: Nhiễu băng rộng (Wide band noise) ≤20mV rms (5Hz - 1MHz)\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, evidence: Output noise Wide band noise ≤20mV rms (5Hz - 1MHz)<br/>Peak-Peak noise ≤250mV p-p (0 - 20MHz)\n\n'],
#   'Yêu cầu với module chỉnh lưu (Rectifier)': ['B24B8',
#    '025C5',
#    'F1737',
#    '58833',
#    '9CDE6',
#    'CCDA9',
#    '99C96',
#    '99432'],
#   'Tính năng của thiết bị nguồn': ['A47FE',
#    '77553',
#    '76EA5',
#    '96636',
#    '79811',
#    '4D39F',
#    '36D7A'],
#   'Khối điều khiển và hiển thị': ['1373A',
#    '1431E',
#    '957DC',
#    '2B0F8',
#    '293B7',
#    '45FA3',
#    '986D7'],
#   'Điều kiện làm việc': ['17887'],
#   'Hệ thống làm mát': ['7CF27'],
#   'Điều kiện bảo hành': ['0EACA'],
#   'Acquy kèm theo': ['95154',
#    '11C4F',
#    '5DC7F',
#    '69A4C',
#    '1D8C6',
#    '7BAC6',
#    '23F86',
#    '054CA',
#    'F7F8A',
#    '7CA42',
#    'C060B']}}

# %%
test

# %%
product_key_test = {
    'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)': {'Yêu cầu chung': ['BCCA8',
   '93C6C',
   '8E2C6',
   '17415',
   'D70B1',
   'ABE44',
   'B4706',
   'Đáp ứng: 4/6 = 67%',
   'Netsure 731 A41 Usermanual.pdf, trang: 11, evidence: The equipment should be unpacked and inspected after it arrives at the installation site. The inspection shall be done by representatives of both the user and Vertiv Co., Ltd. To inspect the equipment, you should open the packing case, take out the packing list and check against the packing list that the equipment is correct and complete. Make sure that the equipment is delivered intact.\n\nnetsure-2100-brochure.pdf, trang: 2, evidence: Specifications are subject to change without notice. November 2018\n\nNetsure-801-brochure.pdf, trang: 4, evidence: | Electrical    | IEC 60950-1, EN 60950-1, UL 60950-1            |\n\nNetsure 731 A41 Usermanual.pdf, trang: 9, trong bảng(figure): None, evidence: The power system is composed of power distribution、rectifier modules and controller module.\n\nNetsure 731 A41 Usermanual.pdf, trang: 35, trong bảng(figure): Figure 5 Accessory showing four components of the battery rack, evidence: Để lắp đặt hoàn chỉnh cho bộ cấp nguồn và nạp acquy, các phụ kiện sau đây được sử dụng: Accessory 1 (main frame), Accessory 2 (support bar), Accessory 3 (long bar), Accessory 4 (small bracket), Expansion bolt, và Fastener.\n\nNetsure-731-A41-user-manual.pdf, trang: 1, evidence: NO_CONTENT_HERE\n\n'],
  'Cấu hình thiết bị nguồn': ['A09AB',
   '9F080',
   '5F95F',
   'FC80B',
   'Đáp ứng: 5/5 = 100%',
   'NetSure -731 A41 Brochure.pdf, trang: 1, trong bảng(figure): None, evidence: | Rectifier            | 4 x R48-3000A3 / R48-3000e3 / R48-3500e3 / R48-3500OE4 |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, evidence: Default: dưới 45℃, 3000W 출력.\n\nnetsure-801-brochure.pdf, trang: 5, trong bảng(figure): Bảng, evidence: Số lượng module chỉnh lưu: 1-20\n\nNetsure 731 A41 Usermanual.pdf, trang: 10, evidence: | Battery MCB                  | 2×125A/1P                       | 2×125A/1P                       | 4×125A/1P                                       |\n\n'],
  'Đầu vào AC': ['5552C',
   '3513E',
   '0C362',
   '80D4F',
   'Đáp ứng',
   'Netsure 731 A41 Usermanual.pdf, trang: 30, evidence: AC input system L＋N＋PE/220Vac；3P＋N＋PE/220Vac\n\nNetsure-731-A41-user-manual.pdf, trang: 30, trong bảng(figure): None, evidence: | AC input | Input voltage range | 85Vac～300Vac |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): Technical and Engineering Data, evidence: Dải tần số AC đầu vào từ 45Hz đến 65Hz.\n\nnetsure-212-c23-datasheet2.pdf, trang: 1, evidence: Fully protected from external lightning surges\n\n'],
  'Đầu ra DC': ['6D7D8',
   '3323F',
   '97B78',
   '070AF',
   '1F101',
   'Đáp ứng: 5/5 = 100%',
   'Netsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): Technical and Engineering Data, evidence: | Nominal output voltage   | －48Vdc |\n\nnetsure-701-series_datasheet_en-asia.pdf, trang: 1, trong bảng(figure): Output Data, evidence: | Operating Voltage Range  | -42 Vdc to -58Vdc |\n\nNetsure-731-A41-user-manual.pdf, trang: 30, trong bảng(figure): None, evidence: | Parameter category | Parameter | Description |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| DC output | Voltage set-point accuracy | ≤1％ |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): None, evidence: Nhiễu băng rộng (Wide band noise) ≤20mV rms (5Hz - 1MHz)\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, evidence: Output noise Wide band noise ≤20mV rms (5Hz - 1MHz)<br/>Peak-Peak noise ≤250mV p-p (0 - 20MHz)\n\n']
    }}

# %%
product_key_test
# Out:
# {'Bộ chuyển đổi nguồn 220VAC/ 48VDC (kèm theo 02 dàn acquy 200Ah)': {'Yêu cầu chung': ['BCCA8',
#    '93C6C',
#    '8E2C6',
#    '17415',
#    'D70B1',
#    'ABE44',
#    'B4706',
#    'Đáp ứng: 4/6 = 67%',
#    'Netsure 731 A41 Usermanual.pdf, trang: 11, evidence: The equipment should be unpacked and inspected after it arrives at the installation site. The inspection shall be done by representatives of both the user and Vertiv Co., Ltd. To inspect the equipment, you should open the packing case, take out the packing list and check against the packing list that the equipment is correct and complete. Make sure that the equipment is delivered intact.\n\nnetsure-2100-brochure.pdf, trang: 2, evidence: Specifications are subject to change without notice. November 2018\n\nNetsure-801-brochure.pdf, trang: 4, evidence: | Electrical    | IEC 60950-1, EN 60950-1, UL 60950-1            |\n\nNetsure 731 A41 Usermanual.pdf, trang: 9, trong bảng(figure): None, evidence: The power system is composed of power distribution、rectifier modules and controller module.\n\nNetsure 731 A41 Usermanual.pdf, trang: 35, trong bảng(figure): Figure 5 Accessory showing four components of the battery rack, evidence: Để lắp đặt hoàn chỉnh cho bộ cấp nguồn và nạp acquy, các phụ kiện sau đây được sử dụng: Accessory 1 (main frame), Accessory 2 (support bar), Accessory 3 (long bar), Accessory 4 (small bracket), Expansion bolt, và Fastener.\n\nNetsure-731-A41-user-manual.pdf, trang: 1, evidence: NO_CONTENT_HERE\n\n'],
#   'Cấu hình thiết bị nguồn': ['A09AB',
#    '9F080',
#    '5F95F',
#    'FC80B',
#    'Đáp ứng: 5/5 = 100%',
#    'NetSure -731 A41 Brochure.pdf, trang: 1, trong bảng(figure): None, evidence: | Rectifier            | 4 x R48-3000A3 / R48-3000e3 / R48-3500e3 / R48-3500OE4 |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, evidence: Default: dưới 45℃, 3000W 출력.\n\nnetsure-801-brochure.pdf, trang: 5, trong bảng(figure): Bảng, evidence: Số lượng module chỉnh lưu: 1-20\n\nNetsure 731 A41 Usermanual.pdf, trang: 10, evidence: | Battery MCB                  | 2×125A/1P                       | 2×125A/1P                       | 4×125A/1P                                       |\n\n'],
#   'Đầu vào AC': ['5552C',
#    '3513E',
#    '0C362',
#    '80D4F',
#    'Đáp ứng',
#    'Netsure 731 A41 Usermanual.pdf, trang: 30, evidence: AC input system L＋N＋PE/220Vac；3P＋N＋PE/220Vac\n\nNetsure-731-A41-user-manual.pdf, trang: 30, trong bảng(figure): None, evidence: | AC input | Input voltage range | 85Vac～300Vac |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): Technical and Engineering Data, evidence: Dải tần số AC đầu vào từ 45Hz đến 65Hz.\n\nnetsure-212-c23-datasheet2.pdf, trang: 1, evidence: Fully protected from external lightning surges\n\n'],
#   'Đầu ra DC': ['6D7D8',
#    '3323F',
#    '97B78',
#    '070AF',
#    '1F101',
#    'Đáp ứng: 5/5 = 100%',
#    'Netsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): Technical and Engineering Data, evidence: | Nominal output voltage   | －48Vdc |\n\nnetsure-701-series_datasheet_en-asia.pdf, trang: 1, trong bảng(figure): Output Data, evidence: | Operating Voltage Range  | -42 Vdc to -58Vdc |\n\nNetsure-731-A41-user-manual.pdf, trang: 30, trong bảng(figure): None, evidence: | Parameter category | Parameter | Description |\n| ------------------------------ | ------------------------------------------------ | ------------------------------------------------------------------------------------------------------------------------------- |\n| DC output | Voltage set-point accuracy | ≤1％ |\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, trong bảng(figure): None, evidence: Nhiễu băng rộng (Wide band noise) ≤20mV rms (5Hz - 1MHz)\n\nNetsure 731 A41 Usermanual.pdf, trang: 30, evidence: Output noise Wide band noise ≤20mV rms (5Hz - 1MHz)<br/>Peak-Peak noise ≤250mV p-p (0 - 20MHz)\n\n']}}

# %%
test

# %%
# !pip install python-docx
# Out:
# Requirement already satisfied: python-docx in d:\study\lammaindex\venv\lib\site-packages (1.2.0)
# Requirement already satisfied: lxml>=3.1.0 in d:\study\lammaindex\venv\lib\site-packages (from python-docx) (6.0.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in d:\study\lammaindex\venv\lib\site-packages (from python-docx) (4.14.1)

# %%
from docx import Document
from docx.shared import Pt
from docx.enum.table import WD_TABLE_ALIGNMENT, WD_ALIGN_VERTICAL
# === Tạo Word document ===
doc = Document()
doc.add_heading("BẢNG TUYÊN BỐ ĐÁP ỨNG VỀ KỸ THUẬT", level=1)

# Tạo bảng 6 cột
table = doc.add_table(rows=1, cols=6)
table.style = 'Table Grid'
table.alignment = WD_TABLE_ALIGNMENT.CENTER

# Header
headers = [
    "Hạng mục số", "Tên hàng hoá",
    "Thông số kỹ thuật và các tiêu chuẩn của hàng hoá trong E-HSMT",
    "Thông số kỹ thuật và các tiêu chuẩn của hàng hoá chào trong E-HSDT",
    "Hồ sơ tham chiếu", "Tình đáp ứng của hàng hoá"
]

for i, text in enumerate(headers):
    cell = table.rows[0].cells[i]
    cell.text = text
    for p in cell.paragraphs:
        for run in p.runs:
            run.font.bold = True
            run.font.size = Pt(10)
    cell.vertical_alignment = WD_ALIGN_VERTICAL.CENTER

# Ghi từng dòng
for product, hang_hoa_dict in product_key_test.items():
    for idx, (ten_hang_hoa, items) in enumerate(hang_hoa_dict.items(), start=1):
        ma_ids = items[:-2]  # Các ID
        dap_ung = items[-2]  # ví dụ: "đáp ứng"
        ho_so = items[-1]    # tài liệu tham chiếu

        # Tổng hợp thông số kỹ thuật
        eh_smt = ""
        eh_hsdt = ""

        for ma in ma_ids:
            if ma in test:
                eh_smt += f"- {test[ma]['yeu_cau_ky_thuat_chi_tiet']}\n"
                eh_hsdt += f"- {test[ma].get('kha_nang_dap_ung',"")}\n"

        # Tạo dòng mới
        row = table.add_row().cells
        row[0].text = str(idx)
        row[1].text = ten_hang_hoa
        row[2].text = eh_smt.strip()
        row[3].text = eh_hsdt.strip()
        row[4].text = ho_so
        row[5].text = dap_ung

        for cell in row:
            cell.vertical_alignment = WD_ALIGN_VERTICAL.TOP
            for p in cell.paragraphs:
                for run in p.runs:
                    run.font.size = Pt(9)

# Lưu file
doc.save("bang_tuyen_bo_dap_ung5.docx")
